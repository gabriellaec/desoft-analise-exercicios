# %% [markdown]
# # Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import matplotlib as mpl
mpl.style.use("seaborn")

# %% [markdown]
# # Analisando os erros de sintaxe

# %%
nome_exercicio="gaussiana"

# %%
json_results= "exercicios/analise-exercicios/"+ nome_exercicio + "/resultado_detalhado.json"
json_results
# Out:
# 'exercicios/analise-exercicios/gaussiana/resultado_detalhado.json'

# %%
df_exs = pd.read_json(json_results, orient='records')
df_exs = df_exs.rename(columns = {'id':'id','erros':'tipo_do_erro', 'resultado':'passou'})

# %%
#df_exs=df_exs.set_index('id')
df_exs.tail(4)
# Out:
#                                                detalhes  \
# 2313  [('line 6\n    return a * b\n         ^\nSynta...
# 2314  [('line 1\n    def x\n        ^\nSyntaxError: ...
# 2315  [('line 4\n    B = math.e^(0.5*((x-mi)/sigma)^...
# 2316  [ in test_1\nAssertionError: <|><Verificar qua...
#
#                                            tipo_do_erro  \
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
# 2316  AssertionError: <|><Verificar quando x ou mi é...
#
#                                      id    linha  passou
# 2313  ch3_2020_03_04_20_08_39_273348.py  'line 6   False
# 2314  ch3_2019_09_11_23_12_24_127271.py  'line 1   False
# 2315  ch3_2020_03_04_19_49_40_592877.py  'line 4   False
# 2316  ch3_2020_09_04_16_47_36_060892.py            False

# %%
df_erros=df_exs[df_exs['passou']==False]

df_erros.head()
# Out:
#                                             detalhes  \
# 1  [('line 3\n    y=((1/σ*(2import.pi)**1/2)impor...
# 2  [ in calcula_gaussiana\nTypeError: \'float\' o...
# 3  [('line 3\n    if x\n       ^\nSyntaxError: in...
# 4  [('line 3\n    y=1/(sigma*(2*math.pi)**0.5)mat...
# 5  [ in calcula_gaussiana\nTypeError: \'float\' o...
#
#                                   tipo_do_erro  \
# 1                  SyntaxError: invalid syntax
# 2  TypeError: \'float\' object is not callable
# 3                  SyntaxError: invalid syntax
# 4                  SyntaxError: invalid syntax
# 5  TypeError: \'float\' object is not callable
#
#                                   id    linha  passou
# 1  ch3_2019_08_13_16_52_03_378932.py  'line 3   False
# 2  ch3_2020_03_09_19_11_49_185208.py            False
# 3  ch3_2020_02_28_17_44_32_436097.py  'line 3   False
# 4  ch3_2019_03_01_12_59_50_648548.py  'line 3   False
# 5  ch3_2020_02_20_00_11_13_695953.py            False

# %%
df_sintaxe = df_erros[df_erros['tipo_do_erro'].str.contains("SyntaxError", na=False)]
df_sintaxe
# Out:
#                                                detalhes  \
# 1     [('line 3\n    y=((1/σ*(2import.pi)**1/2)impor...
# 3     [('line 3\n    if x\n       ^\nSyntaxError: in...
# 4     [('line 3\n    y=1/(sigma*(2*math.pi)**0.5)mat...
# 7      [1))\n        ^\nSyntaxError: invalid syntax\n']
# 11    [ line 6\n    return (1/sigma*math.sqrt(2*math...
# 17    [ pi\n              ^\nSyntaxError: invalid sy...
# 23    [('line 1\n    Import numpy as np\n           ...
# 24    [ 11)\n                          ^\nSyntaxErro...
# 26    [('line 3\n    f=(1/σ*(2* math.pi)**(1/2))*mat...
# 32    [5((x-mi)/sigma)*2)\n                  ^\nSynt...
# 34     [σ)\n         ^\nSyntaxError: invalid syntax\n']
# 36    [ line 2\nSyntaxError: can\'t assign to functi...
# 37    [ line 2\nSyntaxError: can\'t assign to functi...
# 38    [('line 4\n    return calculo\n         ^\nSyn...
# 39    [('line 4\n    return y\n         ^\nSyntaxErr...
# 41    [('line 4\n    return resultado\n         ^\nS...
# 42    [ line 3\n    return  (1/(σ*math.sqrt(2*math.p...
# 48    [('line 5\n    a = y * z\n    ^\nSyntaxError: ...
# 50    [71**(-0.5*((x-mi)/sigma)**2)\n    ^\nSyntaxEr...
# 57    [('line 4\n    return y\n         ^\nSyntaxErr...
# 63     [1))\n        ^\nSyntaxError: invalid syntax\n']
# 65    [('line 5\n    f = a * b\n    ^\nSyntaxError: ...
# 72    [ line 4\n    #return equacao\n               ...
# 74      [0:\n        ^\nSyntaxError: invalid syntax\n']
# 78    [ line 4\nSyntaxError: \'return\' outside func...
# 81    [('line 5\n    return f\n         ^\nSyntaxErr...
# 86    [('line 1\n    math import sqrt\n             ...
# 95    [ 1/sqrt(2*pi))\n                             ...
# 97    [ 1)\n                                   ^\nSy...
# 98    [('line 4\n    return f\n         ^\nSyntaxErr...
# ...                                                 ...
# 2236  [('line 1\n    import.math\n          ^\nSynta...
# 2237  [('line 5\n    return f\n         ^\nSyntaxErr...
# 2238  [('line 4\n    return f\n         ^\nSyntaxErr...
# 2244  [('line 5\n    parte2 = math.exp(-0.5*((x-mi)/...
# 2247  [1/math.sqrt(2*math.pi))\n                    ...
# 2251  [('line 5\n    l = a * b\n    ^\nSyntaxError: ...
# 2256  [('line 6\n    c = a*b\n    ^\nSyntaxError: in...
# 2259  [('line 4\n    return y\n         ^\nSyntaxErr...
# 2262  [('line 4\n    return f\n         ^\nSyntaxErr...
# 2267  [5(x−yz) ** 2)\n                              ...
# 2271  [ pi\n              ^\nSyntaxError: invalid sy...
# 2273  [('line 5\n    return f\n         ^\nSyntaxErr...
# 2275  [('line 5\n    f = (1/(sigma*(2*math.pi)**0.5)...
# 2276  [('line 6\n    c = a*b\n    ^\nSyntaxError: in...
# 2282  [('line 4\n    return form\n         ^\nSyntax...
# 2283  [\\sigma) :\n                                 ...
# 2285  [('line 4\n    return resultado\n         ^\nS...
# 2292  [('line 4\n    return gau\n         ^\nSyntaxE...
# 2293  [sigma)\n                                    ^...
# 2294  [71**(-1/2*((x−mi)/sigma)**2)\n               ...
# 2296  [('line 6\n    d=(a*b)*c\n    ^\nSyntaxError: ...
# 2297  [('line 4\n    return a\n         ^\nSyntaxErr...
# 2299  [('line 4\n    return (1/(σ*(2*math.pi)**0.5))...
# 2305  [5)*((x-mi)/sigma)**2))\n                     ...
# 2307  [5(\\frac{x-\\mu}{\\sigma})^2)}\n             ...
# 2308  [('line 3\n    f=(1/σ(2* math.pi)**1/2)math.ex...
# 2309  [('line 4\n    return calculo\n         ^\nSyn...
# 2313  [('line 6\n    return a * b\n         ^\nSynta...
# 2314  [('line 1\n    def x\n        ^\nSyntaxError: ...
# 2315  [('line 4\n    B = math.e^(0.5*((x-mi)/sigma)^...
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id                                 linha  \
# 1     ch3_2019_08_13_16_52_03_378932.py                               'line 3
# 3     ch3_2020_02_28_17_44_32_436097.py                               'line 3
# 4     ch3_2019_03_01_12_59_50_648548.py                               'line 3
# 7     ch3_2020_03_18_23_48_15_310305.py                             ('line 10
# 11    ch3_2019_03_30_20_28_09_678811.py                                line 6
# 17    ch3_2020_03_09_13_49_29_497280.py                              ('line 1
# 23    ch3_2020_09_21_18_42_03_389570.py                               'line 1
# 24    ch3_2020_08_04_15_47_57_054802.py                              ('line 5
# 26    ch3_2019_08_12_17_09_58_433774.py                               'line 3
# 32    ch3_2020_09_29_19_01_20_963868.py                              ('line 2
# 34    ch3_2019_06_05_01_20_09_945293.py                              ('line 4
# 36    ch3_2020_03_25_19_08_34_352508.py                                line 2
# 37    ch3_2020_03_02_18_45_49_216760.py                                line 2
# 38    ch3_2020_03_09_13_38_03_494630.py                               'line 4
# 39    ch3_2020_03_03_10_10_14_055491.py                               'line 4
# 41    ch3_2019_03_14_19_31_10_022969.py                               'line 4
# 42    ch3_2020_09_23_20_30_53_343376.py                                line 3
# 48    ch3_2020_03_23_14_55_07_251707.py                               'line 5
# 50    ch3_2020_03_31_18_21_08_348102.py                              ('line 4
# 57    ch3_2019_03_11_21_58_43_396919.py                               'line 4
# 63    ch3_2020_03_03_17_29_08_273899.py                             ('line 10
# 65    ch3_2020_03_23_14_54_35_351935.py                               'line 5
# 72    ch3_2020_09_09_12_11_29_735802.py                                line 4
# 74    ch3_2019_03_09_17_39_36_402103.py                              ('line 3
# 78    ch3_2019_08_13_19_43_22_340603.py                                line 4
# 81    ch3_2020_04_10_20_37_39_895697.py                               'line 5
# 86    ch3_2019_08_16_19_15_13_019576.py                               'line 1
# 95    ch3_2020_03_02_21_35_28_782122.py  ('Traceback (most recent call last):
# 97    ch3_2020_03_09_14_03_07_787857.py  ('Traceback (most recent call last):
# 98    ch3_2020_03_09_19_09_40_205386.py                               'line 4
# ...                                 ...                                   ...
# 2236  ch3_2019_03_12_21_10_44_924213.py                               'line 1
# 2237  ch3_2019_05_29_20_31_32_260220.py                               'line 5
# 2238  ch3_2020_09_08_17_30_19_635442.py                               'line 4
# 2244  ch3_2020_03_02_19_45_08_686566.py                               'line 5
# 2247  ch3_2020_04_06_18_54_42_307975.py  ('Traceback (most recent call last):
# 2251  ch3_2020_03_23_14_53_58_631703.py                               'line 5
# 2256  ch3_2020_03_04_20_07_24_339955.py                               'line 6
# 2259  ch3_2019_08_26_20_23_52_343763.py                               'line 4
# 2262  ch3_2019_08_13_18_22_43_129570.py                               'line 4
# 2267  ch3_2020_09_09_12_15_02_756573.py  ('Traceback (most recent call last):
# 2271  ch3_2020_03_09_13_48_29_232954.py                              ('line 1
# 2273  ch3_2020_04_10_20_31_14_492924.py                               'line 5
# 2275  ch3_2019_08_14_13_30_47_108204.py                               'line 5
# 2276  ch3_2020_03_04_20_07_43_567598.py                               'line 6
# 2282  ch3_2020_09_09_12_04_43_548755.py                               'line 4
# 2283  ch3_2020_09_14_14_03_25_072072.py  ('Traceback (most recent call last):
# 2285  ch3_2020_08_31_18_44_55_201192.py                               'line 4
# 2292  ch3_2020_09_09_20_18_58_431532.py                               'line 4
# 2293  ch3_2020_09_09_20_41_11_770857.py                              ('line 3
# 2294  ch3_2020_03_09_20_28_58_798238.py  ('Traceback (most recent call last):
# 2296  ch3_2020_09_09_14_29_37_403356.py                               'line 6
# 2297  ch3_2019_03_29_14_07_34_917203.py                               'line 4
# 2299  ch3_2019_03_07_18_57_42_939362.py                               'line 4
# 2305  ch3_2019_08_21_17_54_12_801185.py                              ('line 3
# 2307  ch3_2020_03_23_10_14_53_153109.py  ('Traceback (most recent call last):
# 2308  ch3_2019_08_12_17_07_36_036992.py                               'line 3
# 2309  ch3_2019_03_13_20_36_46_064099.py                               'line 4
# 2313  ch3_2020_03_04_20_08_39_273348.py                               'line 6
# 2314  ch3_2019_09_11_23_12_24_127271.py                               'line 1
# 2315  ch3_2020_03_04_19_49_40_592877.py                               'line 4
#
#       passou
# 1      False
# 3      False
# 4      False
# 7      False
# 11     False
# 17     False
# 23     False
# 24     False
# 26     False
# 32     False
# 34     False
# 36     False
# 37     False
# 38     False
# 39     False
# 41     False
# 42     False
# 48     False
# 50     False
# 57     False
# 63     False
# 65     False
# 72     False
# 74     False
# 78     False
# 81     False
# 86     False
# 95     False
# 97     False
# 98     False
# ...      ...
# 2236   False
# 2237   False
# 2238   False
# 2244   False
# 2247   False
# 2251   False
# 2256   False
# 2259   False
# 2262   False
# 2267   False
# 2271   False
# 2273   False
# 2275   False
# 2276   False
# 2282   False
# 2283   False
# 2285   False
# 2292   False
# 2293   False
# 2294   False
# 2296   False
# 2297   False
# 2299   False
# 2305   False
# 2307   False
# 2308   False
# 2309   False
# 2313   False
# 2314   False
# 2315   False
#
# [676 rows x 5 columns]

# %%
df_sintaxe["erro"]="--"
df_sintaxe["possivel_solucao"]="--"

# %%
df_sintaxe.head()
# Out:
#                                              detalhes  \
# 1   [('line 3\n    y=((1/σ*(2import.pi)**1/2)impor...
# 3   [('line 3\n    if x\n       ^\nSyntaxError: in...
# 4   [('line 3\n    y=1/(sigma*(2*math.pi)**0.5)mat...
# 7    [1))\n        ^\nSyntaxError: invalid syntax\n']
# 11  [ line 6\n    return (1/sigma*math.sqrt(2*math...
#
#                                  tipo_do_erro  \
# 1                 SyntaxError: invalid syntax
# 3                 SyntaxError: invalid syntax
# 4                 SyntaxError: invalid syntax
# 7                 SyntaxError: invalid syntax
# 11  SyntaxError: unexpected EOF while parsing
#
#                                    id      linha  passou erro possivel_solucao
# 1   ch3_2019_08_13_16_52_03_378932.py    'line 3   False   --               --
# 3   ch3_2020_02_28_17_44_32_436097.py    'line 3   False   --               --
# 4   ch3_2019_03_01_12_59_50_648548.py    'line 3   False   --               --
# 7   ch3_2020_03_18_23_48_15_310305.py  ('line 10   False   --               --
# 11  ch3_2019_03_30_20_28_09_678811.py     line 6   False   --               --

# %% [markdown]
# ## Adicionando os IDs dos usuários ao dataframe

# %%
import os

def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.join(root, name))
    return r

# %%
dir = r"C:\Users\gabic\Documents\NINJA_DeSoft\submissoes_servidor\backup"
files = list_files(dir)

# %%
lista_files = []
for f in files:
    f = f[65:]
    f.replace("//","/")
    lista_files.append(f)
    
lista_files= lista_files[1:]

# %%
df_sintaxe["usuario"]="--"
for ind in df_sintaxe.index: 
        for l in lista_files:
            user = l[0:8]
            ex = l[9:]
            if ex == df_sintaxe["id"][ind]:
                df_sintaxe["usuario"][ind] = user
#                 print(user)
#                 print(ex)

# %%
df_sintaxe
# Out:
#                                                detalhes  \
# 1                                        invalid syntax
# 3                                        invalid syntax
# 4                                        invalid syntax
# 7                                        invalid syntax
# 11                         unexpected EOF while parsing
# 17                                       invalid syntax
# 23                                       invalid syntax
# 24                                       invalid syntax
# 26                                       invalid syntax
# 32                                       invalid syntax
# 34                                       invalid syntax
# 36                        can\t assign to function call
# 37                        can\t assign to function call
# 38                                       invalid syntax
# 39                                       invalid syntax
# 41                                       invalid syntax
# 42                         unexpected EOF while parsing
# 48                                       invalid syntax
# 50                                       invalid syntax
# 57                                       invalid syntax
# 63                                       invalid syntax
# 65                                       invalid syntax
# 72                         unexpected EOF while parsing
# 74                                       invalid syntax
# 78                            \return\ outside function
# 81                                       invalid syntax
# 86                                       invalid syntax
# 95                         unexpected EOF while parsing
# 97                         unexpected EOF while parsing
# 98                                       invalid syntax
# ...                                                 ...
# 2236                                     invalid syntax
# 2237                                     invalid syntax
# 2238                                     invalid syntax
# 2244                                     invalid syntax
# 2247                       unexpected EOF while parsing
# 2251                                     invalid syntax
# 2256                                     invalid syntax
# 2259                                     invalid syntax
# 2262                                     invalid syntax
# 2267                    invalid character in identifier
# 2271                                     invalid syntax
# 2273                                     invalid syntax
# 2275                                     invalid syntax
# 2276                                     invalid syntax
# 2282                                     invalid syntax
# 2283   unexpected character after line continuation ...
# 2285                                     invalid syntax
# 2292                                     invalid syntax
# 2293                                     invalid syntax
# 2294                    invalid character in identifier
# 2296                                     invalid syntax
# 2297                                     invalid syntax
# 2299                                     invalid syntax
# 2305                                     invalid syntax
# 2307   unexpected character after line continuation ...
# 2308                                     invalid syntax
# 2309                                     invalid syntax
# 2313                                     invalid syntax
# 2314                                     invalid syntax
# 2315                                     invalid syntax
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id    linha  passou  \
# 1     ch3_2019_08_13_16_52_03_378932.py   line 3   False
# 3     ch3_2020_02_28_17_44_32_436097.py   line 3   False
# 4     ch3_2019_03_01_12_59_50_648548.py   line 3   False
# 7     ch3_2020_03_18_23_48_15_310305.py  line 10   False
# 11    ch3_2019_03_30_20_28_09_678811.py   line 6   False
# 17    ch3_2020_03_09_13_49_29_497280.py   line 1   False
# 23    ch3_2020_09_21_18_42_03_389570.py   line 1   False
# 24    ch3_2020_08_04_15_47_57_054802.py   line 5   False
# 26    ch3_2019_08_12_17_09_58_433774.py   line 3   False
# 32    ch3_2020_09_29_19_01_20_963868.py   line 2   False
# 34    ch3_2019_06_05_01_20_09_945293.py   line 4   False
# 36    ch3_2020_03_25_19_08_34_352508.py   line 2   False
# 37    ch3_2020_03_02_18_45_49_216760.py   line 2   False
# 38    ch3_2020_03_09_13_38_03_494630.py   line 4   False
# 39    ch3_2020_03_03_10_10_14_055491.py   line 4   False
# 41    ch3_2019_03_14_19_31_10_022969.py   line 4   False
# 42    ch3_2020_09_23_20_30_53_343376.py   line 3   False
# 48    ch3_2020_03_23_14_55_07_251707.py   line 5   False
# 50    ch3_2020_03_31_18_21_08_348102.py   line 4   False
# 57    ch3_2019_03_11_21_58_43_396919.py   line 4   False
# 63    ch3_2020_03_03_17_29_08_273899.py  line 10   False
# 65    ch3_2020_03_23_14_54_35_351935.py   line 5   False
# 72    ch3_2020_09_09_12_11_29_735802.py   line 4   False
# 74    ch3_2019_03_09_17_39_36_402103.py   line 3   False
# 78    ch3_2019_08_13_19_43_22_340603.py   line 4   False
# 81    ch3_2020_04_10_20_37_39_895697.py   line 5   False
# 86    ch3_2019_08_16_19_15_13_019576.py   line 1   False
# 95    ch3_2020_03_02_21_35_28_782122.py       --   False
# 97    ch3_2020_03_09_14_03_07_787857.py       --   False
# 98    ch3_2020_03_09_19_09_40_205386.py   line 4   False
# ...                                 ...      ...     ...
# 2236  ch3_2019_03_12_21_10_44_924213.py   line 1   False
# 2237  ch3_2019_05_29_20_31_32_260220.py   line 5   False
# 2238  ch3_2020_09_08_17_30_19_635442.py   line 4   False
# 2244  ch3_2020_03_02_19_45_08_686566.py   line 5   False
# 2247  ch3_2020_04_06_18_54_42_307975.py       --   False
# 2251  ch3_2020_03_23_14_53_58_631703.py   line 5   False
# 2256  ch3_2020_03_04_20_07_24_339955.py   line 6   False
# 2259  ch3_2019_08_26_20_23_52_343763.py   line 4   False
# 2262  ch3_2019_08_13_18_22_43_129570.py   line 4   False
# 2267  ch3_2020_09_09_12_15_02_756573.py       --   False
# 2271  ch3_2020_03_09_13_48_29_232954.py   line 1   False
# 2273  ch3_2020_04_10_20_31_14_492924.py   line 5   False
# 2275  ch3_2019_08_14_13_30_47_108204.py   line 5   False
# 2276  ch3_2020_03_04_20_07_43_567598.py   line 6   False
# 2282  ch3_2020_09_09_12_04_43_548755.py   line 4   False
# 2283  ch3_2020_09_14_14_03_25_072072.py       --   False
# 2285  ch3_2020_08_31_18_44_55_201192.py   line 4   False
# 2292  ch3_2020_09_09_20_18_58_431532.py   line 4   False
# 2293  ch3_2020_09_09_20_41_11_770857.py   line 3   False
# 2294  ch3_2020_03_09_20_28_58_798238.py       --   False
# 2296  ch3_2020_09_09_14_29_37_403356.py   line 6   False
# 2297  ch3_2019_03_29_14_07_34_917203.py   line 4   False
# 2299  ch3_2019_03_07_18_57_42_939362.py   line 4   False
# 2305  ch3_2019_08_21_17_54_12_801185.py   line 3   False
# 2307  ch3_2020_03_23_10_14_53_153109.py       --   False
# 2308  ch3_2019_08_12_17_07_36_036992.py   line 3   False
# 2309  ch3_2019_03_13_20_36_46_064099.py   line 4   False
# 2313  ch3_2020_03_04_20_08_39_273348.py   line 6   False
# 2314  ch3_2019_09_11_23_12_24_127271.py   line 1   False
# 2315  ch3_2020_03_04_19_49_40_592877.py   line 4   False
#
#                                                    erro possivel_solucao  \
# 1     Verifique a maneira com que está realizando o ...               --
# 3                           Faltou ':' na linha do 'if'               --
# 4                                                    --               --
# 7                                                    --               --
# 11                          Faltou fechar um parênteses               --
# 17                                                   --               --
# 23    Verifique a maneira com que está realizando o ...               --
# 24                                                   --               --
# 26                                                   --               --
# 32                                                   --               --
# 34                                                   --               --
# 36                                                   --               --
# 37                                                   --               --
# 38                    Verifique a linha antes do return               --
# 39                    Verifique a linha antes do return               --
# 41                    Verifique a linha antes do return               --
# 42                          Faltou fechar um parênteses               --
# 48                                                   --               --
# 50                                                   --               --
# 57                    Verifique a linha antes do return               --
# 63                                                   --               --
# 65                                                   --               --
# 72                                                   --               --
# 74                                                   --               --
# 78                                                   --               --
# 81                    Verifique a linha antes do return               --
# 86    Verifique a maneira com que está realizando o ...               --
# 95                                                   --               --
# 97                                                   --               --
# 98                    Verifique a linha antes do return               --
# ...                                                 ...              ...
# 2236  Verifique a maneira com que está realizando o ...               --
# 2237                  Verifique a linha antes do return               --
# 2238                  Verifique a linha antes do return               --
# 2244                                                 --               --
# 2247                                                 --               --
# 2251                                                 --               --
# 2256                                                 --               --
# 2259                  Verifique a linha antes do return               --
# 2262                  Verifique a linha antes do return               --
# 2267                                                 --               --
# 2271                                                 --               --
# 2273                  Verifique a linha antes do return               --
# 2275                                                 --               --
# 2276                                                 --               --
# 2282                       Faltou ':' na linha do 'for'               --
# 2283                                                 --               --
# 2285                  Verifique a linha antes do return               --
# 2292                  Verifique a linha antes do return               --
# 2293                                                 --               --
# 2294                                                 --               --
# 2296                                                 --               --
# 2297                  Verifique a linha antes do return               --
# 2299                                                 --               --
# 2305                                                 --               --
# 2307                                                 --               --
# 2308                                                 --               --
# 2309                  Verifique a linha antes do return               --
# 2313                  Verifique a linha antes do return               --
# 2314                       Faltou ':' na linha do 'def'               --
# 2315                           Potência em Python é: **               --
#
#        usuario
# 1     user_086
# 3     user_321
# 4     user_236
# 7     user_230
# 11    user_154
# 17    user_192
# 23    user_104
# 24    user_051
# 26    user_370
# 32    user_060
# 34    user_171
# 36    user_118
# 37    user_230
# 38    user_208
# 39    user_229
# 41    user_330
# 42    user_314
# 48    user_252
# 50    user_372
# 57    user_343
# 63    user_230
# 65    user_252
# 72    user_113
# 74    user_399
# 78    user_302
# 81    user_158
# 86    user_350
# 95    user_162
# 97    user_299
# 98    user_367
# ...        ...
# 2236  user_176
# 2237  user_004
# 2238  user_152
# 2244  user_242
# 2247  user_230
# 2251  user_252
# 2256  user_123
# 2259  user_305
# 2262  user_086
# 2267  user_206
# 2271  user_192
# 2273  user_158
# 2275  user_011
# 2276  user_123
# 2282  user_113
# 2283  user_019
# 2285  user_121
# 2292  user_003
# 2293  user_088
# 2294  user_372
# 2296  user_017
# 2297  user_189
# 2299  user_346
# 2305  user_099
# 2307  user_106
# 2308  user_370
# 2309  user_330
# 2313  user_123
# 2314  user_168
# 2315  user_181
#
# [676 rows x 8 columns]

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
d=[]
l=[]
i=[]
e=[]
log=[]
for ind in df_sintaxe.index: 
    line = df_sintaxe["linha"][ind]
    det = df_sintaxe["detalhes"][ind]
    df_sintaxe["linha"][ind]=line
    
    line=line.replace("(","")
    line=line.replace("('","")
    line=line.replace("'","")

    df_sintaxe["linha"][ind]=line

#     error=df_sintaxe["erros"][ind]
    if str("line") not in line:
        df_sintaxe["linha"][ind]= "--"
    for x in det:
        x=x.replace("\\n","")
        x=x.replace("   ^","")
        details = find_between(x, "line", "SyntaxError" )
#         print(details[2:])
        df_sintaxe["erro"][ind]=details[4:]
#         det_list=x.split()
#         for d in det_list:
#             if "*" in d:
#                 print("")
#             else:
#                print(x)
#         print(det_list)
#         if ("*") in det_list[2]:
#             print(" ")
#         else:
#             print(det_list)
#        df_sintaxe["erro"]=det_list[2]
#             print(" ")            
#         print (det)
        
#         print(x)
        if "SyntaxError" in x:
            detail=x[x.index("SyntaxError:") + len("SyntaxError:"):]
            detail=detail.replace("'", "")
            detail=detail.replace(")", "")
            df_sintaxe["detalhes"][ind]=detail


#         if det not in d:         
# #             d.append(det)
#             strdet=str(det)
#             strdet=strdet.replace("  ","")
#             det_filtrado = strdet.split(r"\\n")
#             d.append(det_filtrado)
# #             for detalhe in (det):
# #                 print(detalhe)
            
#         l.append("["+ line+ "]")
#         i.append("["+ str(ind)+ "]")
# #         print(df_sintaxe.loc[[ind]])
#         log.append(df_sintaxe.loc[[ind]])
#         e.append(error)

# %%
df_sintaxe
# Out:
#                                                detalhes  \
# 1                                        invalid syntax
# 3                                        invalid syntax
# 4                                        invalid syntax
# 7                                        invalid syntax
# 11                         unexpected EOF while parsing
# 17                                       invalid syntax
# 23                                       invalid syntax
# 24                                       invalid syntax
# 26                                       invalid syntax
# 32                                       invalid syntax
# 34                                       invalid syntax
# 36                        can\t assign to function call
# 37                        can\t assign to function call
# 38                                       invalid syntax
# 39                                       invalid syntax
# 41                                       invalid syntax
# 42                         unexpected EOF while parsing
# 48                                       invalid syntax
# 50                                       invalid syntax
# 57                                       invalid syntax
# 63                                       invalid syntax
# 65                                       invalid syntax
# 72                         unexpected EOF while parsing
# 74                                       invalid syntax
# 78                            \return\ outside function
# 81                                       invalid syntax
# 86                                       invalid syntax
# 95                         unexpected EOF while parsing
# 97                         unexpected EOF while parsing
# 98                                       invalid syntax
# ...                                                 ...
# 2236                                     invalid syntax
# 2237                                     invalid syntax
# 2238                                     invalid syntax
# 2244                                     invalid syntax
# 2247                       unexpected EOF while parsing
# 2251                                     invalid syntax
# 2256                                     invalid syntax
# 2259                                     invalid syntax
# 2262                                     invalid syntax
# 2267                    invalid character in identifier
# 2271                                     invalid syntax
# 2273                                     invalid syntax
# 2275                                     invalid syntax
# 2276                                     invalid syntax
# 2282                                     invalid syntax
# 2283   unexpected character after line continuation ...
# 2285                                     invalid syntax
# 2292                                     invalid syntax
# 2293                                     invalid syntax
# 2294                    invalid character in identifier
# 2296                                     invalid syntax
# 2297                                     invalid syntax
# 2299                                     invalid syntax
# 2305                                     invalid syntax
# 2307   unexpected character after line continuation ...
# 2308                                     invalid syntax
# 2309                                     invalid syntax
# 2313                                     invalid syntax
# 2314                                     invalid syntax
# 2315                                     invalid syntax
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id    linha  passou  \
# 1     ch3_2019_08_13_16_52_03_378932.py   line 3   False
# 3     ch3_2020_02_28_17_44_32_436097.py   line 3   False
# 4     ch3_2019_03_01_12_59_50_648548.py   line 3   False
# 7     ch3_2020_03_18_23_48_15_310305.py  line 10   False
# 11    ch3_2019_03_30_20_28_09_678811.py   line 6   False
# 17    ch3_2020_03_09_13_49_29_497280.py   line 1   False
# 23    ch3_2020_09_21_18_42_03_389570.py   line 1   False
# 24    ch3_2020_08_04_15_47_57_054802.py   line 5   False
# 26    ch3_2019_08_12_17_09_58_433774.py   line 3   False
# 32    ch3_2020_09_29_19_01_20_963868.py   line 2   False
# 34    ch3_2019_06_05_01_20_09_945293.py   line 4   False
# 36    ch3_2020_03_25_19_08_34_352508.py   line 2   False
# 37    ch3_2020_03_02_18_45_49_216760.py   line 2   False
# 38    ch3_2020_03_09_13_38_03_494630.py   line 4   False
# 39    ch3_2020_03_03_10_10_14_055491.py   line 4   False
# 41    ch3_2019_03_14_19_31_10_022969.py   line 4   False
# 42    ch3_2020_09_23_20_30_53_343376.py   line 3   False
# 48    ch3_2020_03_23_14_55_07_251707.py   line 5   False
# 50    ch3_2020_03_31_18_21_08_348102.py   line 4   False
# 57    ch3_2019_03_11_21_58_43_396919.py   line 4   False
# 63    ch3_2020_03_03_17_29_08_273899.py  line 10   False
# 65    ch3_2020_03_23_14_54_35_351935.py   line 5   False
# 72    ch3_2020_09_09_12_11_29_735802.py   line 4   False
# 74    ch3_2019_03_09_17_39_36_402103.py   line 3   False
# 78    ch3_2019_08_13_19_43_22_340603.py   line 4   False
# 81    ch3_2020_04_10_20_37_39_895697.py   line 5   False
# 86    ch3_2019_08_16_19_15_13_019576.py   line 1   False
# 95    ch3_2020_03_02_21_35_28_782122.py       --   False
# 97    ch3_2020_03_09_14_03_07_787857.py       --   False
# 98    ch3_2020_03_09_19_09_40_205386.py   line 4   False
# ...                                 ...      ...     ...
# 2236  ch3_2019_03_12_21_10_44_924213.py   line 1   False
# 2237  ch3_2019_05_29_20_31_32_260220.py   line 5   False
# 2238  ch3_2020_09_08_17_30_19_635442.py   line 4   False
# 2244  ch3_2020_03_02_19_45_08_686566.py   line 5   False
# 2247  ch3_2020_04_06_18_54_42_307975.py       --   False
# 2251  ch3_2020_03_23_14_53_58_631703.py   line 5   False
# 2256  ch3_2020_03_04_20_07_24_339955.py   line 6   False
# 2259  ch3_2019_08_26_20_23_52_343763.py   line 4   False
# 2262  ch3_2019_08_13_18_22_43_129570.py   line 4   False
# 2267  ch3_2020_09_09_12_15_02_756573.py       --   False
# 2271  ch3_2020_03_09_13_48_29_232954.py   line 1   False
# 2273  ch3_2020_04_10_20_31_14_492924.py   line 5   False
# 2275  ch3_2019_08_14_13_30_47_108204.py   line 5   False
# 2276  ch3_2020_03_04_20_07_43_567598.py   line 6   False
# 2282  ch3_2020_09_09_12_04_43_548755.py   line 4   False
# 2283  ch3_2020_09_14_14_03_25_072072.py       --   False
# 2285  ch3_2020_08_31_18_44_55_201192.py   line 4   False
# 2292  ch3_2020_09_09_20_18_58_431532.py   line 4   False
# 2293  ch3_2020_09_09_20_41_11_770857.py   line 3   False
# 2294  ch3_2020_03_09_20_28_58_798238.py       --   False
# 2296  ch3_2020_09_09_14_29_37_403356.py   line 6   False
# 2297  ch3_2019_03_29_14_07_34_917203.py   line 4   False
# 2299  ch3_2019_03_07_18_57_42_939362.py   line 4   False
# 2305  ch3_2019_08_21_17_54_12_801185.py   line 3   False
# 2307  ch3_2020_03_23_10_14_53_153109.py       --   False
# 2308  ch3_2019_08_12_17_07_36_036992.py   line 3   False
# 2309  ch3_2019_03_13_20_36_46_064099.py   line 4   False
# 2313  ch3_2020_03_04_20_08_39_273348.py   line 6   False
# 2314  ch3_2019_09_11_23_12_24_127271.py   line 1   False
# 2315  ch3_2020_03_04_19_49_40_592877.py   line 4   False
#
#                                                    erro possivel_solucao
# 1       y=((1/σ*(2import.pi)**1/2)import exp(-0.5(x-...               --
# 3                                              if x                   --
# 4       y=1/(sigma*(2*math.pi)**0.5)math.e**(-0.5*((...               --
# 7                                                                     --
# 11      return (1/sigma*math.sqrt(2*math.pi))*math.e...               --
# 17                                                                    --
# 23                       Import numpy as np                           --
# 24                                                                    --
# 26      f=(1/σ*(2* math.pi)**(1/2))*math.exp(-0.5*((...               --
# 32                                                                    --
# 34                                                                    --
# 36                                                                    --
# 37                                                                    --
# 38                                 return calculo                     --
# 39                                       return y                     --
# 41                               return resultado                     --
# 42      return  (1/(σ*math.sqrt(2*math.pi))*math.exp...               --
# 48                                           a = y * z                --
# 50                                                                    --
# 57                                       return y                     --
# 63                                                                    --
# 65                                           f = a * b                --
# 72                       #return equacao                              --
# 74                                                                    --
# 78                                                                    --
# 81                                       return f                     --
# 86                          math import sqrt                          --
# 95                                                                    --
# 97                                                                    --
# 98                                       return f                     --
# ...                                                 ...              ...
# 2236                                 import.math                      --
# 2237                                     return f                     --
# 2238                                     return f                     --
# 2244    parte2 = math.exp(-0.5*((x-mi)/sigma)**2)                     --
# 2247                                                                  --
# 2251                                         l = a * b                --
# 2256                                           c = a*b                --
# 2259                                     return y                     --
# 2262                                     return f                     --
# 2267                                                                  --
# 2271                                                                  --
# 2273                                     return f                     --
# 2275    f = (1/(sigma*(2*math.pi)**0.5))math.exp(-0....               --
# 2276                                           c = a*b                --
# 2282                                  return form                     --
# 2283                                                                  --
# 2285                             return resultado                     --
# 2292                                   return gau                     --
# 2293                                                                  --
# 2294                                                                  --
# 2296                                         d=(a*b)*c                --
# 2297                                     return a                     --
# 2299    return (1/(σ*(2*math.pi)**0.5))**(-0.5*((x-μ...               --
# 2305                                                                  --
# 2307                                                                  --
# 2308    f=(1/σ(2* math.pi)**1/2)math.exp(-0.5*((x-μ)...               --
# 2309                               return calculo                     --
# 2313                                 return a * b                     --
# 2314                                         def x                    --
# 2315                 B = math.e^(0.5*((x-mi)/sigma)^2)                --
#
# [676 rows x 7 columns]

# %%
erro_import=0
erro_antes_do_return=0
erro_parenteses=0
erro_potencia=0
erro_if=0
erro_while=0
erro_for=0
erro_def=0
erro_pi=0
erro_vezes=0

# %%
lista_tipos_erros=[]
for ind in df_sintaxe.index: 
    sol='--'
    erro = df_sintaxe["erro"][ind]
    erro=str(erro)
    
    if "return" in erro and len(erro)<30:
        sol="Verifique a linha antes do return"
        erro_antes_do_return+=1
    if "import" in erro or "Import" in erro:
        sol="Verifique a maneira com que está realizando o import"
        erro_import+=1
    if "(" in erro:
        abre_parenteses=erro.count('(')
        fecha_parenteses=erro.count(')')
        if abre_parenteses>fecha_parenteses:
            sol="Faltou fechar um parênteses"
        elif abre_parenteses<fecha_parenteses:
            sol="Faltou abrir um parênteses"
        erro_parenteses+=1
        
    if "^" in erro:
        sol="Potência em Python é: **"
        erro_potencia+=1
        
    if "if" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'if'"
        erro_if+=1
        
    if "while" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'while'"
        erro_while+=1
        
    if "for" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'for'"
        erro_for+=1
        
    if "def" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'def'"
        erro_def+=1
        
    if "π" in erro:
        sol="π é math.pi"
        erro_pi+=1
        
    if ")(" in erro:
        sol="esqueceu o sinal de *"
        erro_vezes+=1
        
    else:
        lista_tipos_erros.append(erro)
        
    df_sintaxe["solucao"][ind]= sol

# %%
erros = {'tipos': ["erro_import", "erro_antes_do_return", "erro_parenteses", "erro_potencia", "erro_if", "erro_while", "erro_for", "erro_def", "erro_pi", "erro_vezes"],
        'quantidade': [erro_import,erro_antes_do_return,erro_parenteses,erro_potencia,erro_if, erro_while,erro_for, erro_def, erro_pi,erro_vezes]
        }

df_classificacao = pd.DataFrame(erros, columns = ['tipos', 'quantidade'])

# %%
df_classificacao.set_index("tipos")
# Out:
#                       quantidade
# tipos
# erro_import                   35
# erro_antes_do_return         190
# erro_parenteses              219
# erro_potencia                  3
# erro_if                        8
# erro_while                     0
# erro_for                       5
# erro_def                       1
# erro_pi                       11
# erro_vezes                     4

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_axes([0,0,1,1])
ax.bar(df_classificacao["tipos"], df_classificacao["quantidade"])
plt.show()

# %%
df_classificacao.quantidade.sum()
# Out:
# 476

# %%
lista_tipos_erros
# Out:
# ['  y=((1/σ*(2import.pi)**1/2)import exp(-0.5(x-μ)/σ)**2)                ',
#  '  if x    ',
#  '  y=1/(sigma*(2*math.pi)**0.5)math.e**(-0.5*((x-mi)/sigma)**2)                                ',
#  '',
#  '  return (1/sigma*math.sqrt(2*math.pi))*math.exp(-0.5((x - mi)/sigma)**2                                                                      ',
#  '',
#  '  Import numpy as np            ',
#  '',
#  '  f=(1/σ*(2* math.pi)**(1/2))*math.exp(-0.5*((x-μ)/σ)**2):                                                        ',
#  '',
#  '',
#  '',
#  '',
#  '  return calculo      ',
#  '  return y      ',
#  '  return resultado      ',
#  '  return  (1/(σ*math.sqrt(2*math.pi))*math.exp(-0.5*((x-μ)/σ)**2)                                                               ',
#  '  a = y * z ',
#  '',
#  '  return y      ',
#  '',
#  '  f = a * b ',
#  '  #return equacao               ',
#  '',
#  '',
#  '  return f      ',
#  '  math import sqrt           ',
#  '',
#  '',
#  '  return f      ',
#  '  f=(1/a)*e**c ',
#  '  return f      ',
#  '  parte2 = math.exp(-0.5*((a-b)/c)**2)      ',
#  '',
#  '  return f      ',
#  '  return (1/(sigma*math.sqrt(2*math.pi))*(math.e**(-0.5*((x-mi)/sigma)**2))                                                                         ',
#  '  return y      ',
#  '  return resultado      ',
#  '  c = [1 / (math.sigma)*(2(math.pi))**0.5)]*e**(-0.5((x-math.mi)/(math.sigma))**2                                        ',
#  '  f = (1/(sigma*(2*math.pi)**0.5))exp(-0.5((x - mi)/sigma)**2)                                   ',
#  '  return calculo      ',
#  '',
#  '  parte2 = math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '  import.math       ',
#  '  return y      ',
#  '  return f      ',
#  '  return calculo      ',
#  '  import.math       ',
#  '  x=d*e*f ',
#  '  return (1/(sig*math.aqrt(2*math.pi)) * math.exp ** (-0.5*((x - mi)/sig)**2)                                                                           ',
#  '',
#  '  return ((1 / (s * math.sqrt(math.pi * 2)) * math.exp (- 0.5 * (x - m / s) ** 2))                                                                                ',
#  '  return (1/(sigma*math.sqrt(2*math.pi))*math.exp(-0.5*(((x-mi))/sigma)**2)                                                                         ',
#  '  return f      ',
#  '  f = a * b ',
#  '  a=1/(sigma*((2*math.pi)*(1/2))math.exp(-0.5*((x-mi)/sigma)**2)                                  ',
#  '  y=((1/σ(2import pi)**1/2)import exp(-0.5(x-μ)/σ))               ',
#  '',
#  '  return cg      ',
#  '',
#  '  return f      ',
#  '  return gaussiana      ',
#  '  calcula_gaussiana=(1/(σ**0.5*math.pi))math.exp*(-0.5*(x-μ/σ)**2)                                          ',
#  '',
#  '',
#  '  return(parte1*parte2)      ',
#  '',
#  '',
#  '',
#  '  return cg      ',
#  '',
#  '  return (parte1*parte2)      ',
#  '',
#  '  return a      ',
#  '  return a      ',
#  '  return y      ',
#  '  return y      ',
#  '',
#  '  parte2 = math.exp(-0.5*(((a-b)/c)**2))      ',
#  '',
#  '',
#  '  return f      ',
#  '  return((math.e**(-(1/2)*((x-u)/o)**2)/o*math.sqrt(2*math.pi))                                                             ',
#  '  return f      ',
#  '  return f      ',
#  '  s=(1**(-1/2)*(x-μ/σ)**2)σ**1/2*2*math.pi                         ',
#  '  return f      ',
#  '',
#  '  f = 1/σ * sqrt(2* pi) * e((−0.5)*(x−yz) ** 2)                             ',
#  '  return f      ',
#  '',
#  '  f= (1/(sigma*(2*math.pi))**1/2)math.exp(-0.5*((x-mi)/sigma)**2)                                   ',
#  '  import.math       ',
#  '  return f      ',
#  '  y=((2*math.pi)**(1/2))*math.exp**(-0.5*((x-mi)/sigma)**2))/(sigma*2*math.pi)                                                          ',
#  '  y=(1/sigma*math.sqrt(2*math.pi))*math.e**(-0.5((x*mi)/sigma)**2))                                                                 ',
#  '  resultado = 1/(sigma*math.sqrt(2*math.pi))math.exp(-0.5*((x-mi)/sigma)**2)                                              ',
#  '  f = (1/sigma*(2* math.pi)**1/2)** (- o.5((x - mi)/ sigma)**2)                                        ',
#  '',
#  '  b=math.exp**((-0.5)*((x-mi)/sigma)**2)) ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '  f = (1/σ*(2* math.pi)**1/2)** (- o.5((x - μ)/ σ)**2)                                    ',
#  '  return a      ',
#  '  f=(1/σ*(2* math.pi)**1/2)math.exp(-0.5*((x-μ)/σ)**2)                             ',
#  '',
#  '  y=(1/sigma*math.sqrt(2*math.pi))*math.e**(-0.5((x*mi)/sigma)**2))                                                                 ',
#  '  return ((1/a)*b**c)      ',
#  '  y=1/σ*(2*math.pi)**(1/2))*math.exp(-0.5*((x-μ)/σ)**2)                         ',
#  '',
#  '  return y      ',
#  '',
#  '  f = 1/σ * sqrt(2* pi) * e(-(0.5)*(x−y * z) ** 2)                                     ',
#  '',
#  '  f = 1/σ * sqrt(2* pi) * e(-(0.5)*(x−yz) ** 2)                                      ',
#  '  return y      ',
#  '  l=a * b ',
#  '',
#  '  calcula_gaussiana=(1/(σ**1/2*math.pi))math.exp*(-0.5*((x-μ/σ)**2))                                          ',
#  '  final = parte1 * parte 2                        ',
#  '  d=a*b*c ',
#  '',
#  '',
#  '  gauss = a * b     ',
#  '  if x(0)       ',
#  '  y=1/c*2*math.pi**1/2 math.exp(-1/2(a-b/c)**2)                         ',
#  '  return (parte1)      ',
#  '  sigma =! 0        ',
#  '  return resultado      ',
#  '  z = 1/(o*2 mathpi **0.5)                 ',
#  '  gauss = (1/sigma*(2*math.pi)**0.5)math.exp(-0.5*(x - mi/sigma)**2)                                      ',
#  '  return ((1/(s*math.sqrt(math.pi*2))*(math.exp(-0.5*((x-m)/s)**2)))                                                                  ',
#  '  return calculo      ',
#  '  g = (1/ sigma * (2* math.pi)** 1/2) math.exp (-1/2*(x-mi/sigma)**2)                                        ',
#  '  return f      ',
#  '  calcula_gaussiana=(1/(σ**0.5*math.pi))math.exp*-0.5*((x-μ/σ)**2)                                          ',
#  '',
#  '  y=(1/(σ*((2π)**(1/2))))*e**(-0.5*((x-μ)/σ)**2)            ',
#  '  z = 1/(o*2 math.pi **0.5)               ',
#  '  return(1/(σ(2π)**2)*e**(-0.5((x-μ)/σ)**2)              ',
#  '  y=(1/σ*(2*import.pi)**(1/2)import.exp(-0.5(x-μ)/σ)**2)                ',
#  '  y=(1/sigma*(2*math.pi**(1/2)))exp(-0.5*((x-mi)/sigma)**2)                                 ',
#  '   ',
#  '  return (1/(sigma*math.sqrt(2*math.pi))) * math.e ** (-0.5*((x - mi)/sig)**2                                                                           ',
#  '  y = (1/(σ*(2*math.pi)**(1/2))*math.exp((-1/2)*((x-μ)/σ)**2);                                                            ',
#  '  y=1/(σ*(2π)**(1/2))*e*(-0.5((x-μ)/σ)**2)          ',
#  '',
#  '  return resultado      ',
#  '  return((1/σ*sqrt(2math.pi))*e**(-0.5*(x-μ/σ)**2))                      ',
#  '  parte2 = math.exp(-0.5*(((a-b)/c)**2))      ',
#  '',
#  '  return f      ',
#  '',
#  '  import.math       ',
#  '  return f      ',
#  '  return f      ',
#  '  w= 1/(z*(2π)**(1/2))*e**(-0.5*(x-y/z)**2)           ',
#  '  return(1/(σ*(math.sqrt(2*math.pi))*math.exp(-0.5*(((x-μ)/σ)**2)))                                                                 ',
#  '  return cg      ',
#  '',
#  '  return f      ',
#  '  return y      ',
#  '  return resposta      ',
#  '  return f      ',
#  '  y = (1/(σ*(2*π)**(1/2)))*e**(-0.5*((x-μ)/σ)**2))                                                ',
#  '  return form      ',
#  '  return f      ',
#  '  return a      ',
#  '  parte2 = math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '  y=(1/(s*(2*math.pi)**(1/2)))math.exp(-0.5((x-m)/s)**2)                                ',
#  '  in=(math.sqrt(2*math.pi))**-1  ',
#  '  return gaussiana      ',
#  '  y=((1/σ*(2import.pi)**1/2)import.exp(-0.5(x-μ)/σ)**2)                ',
#  '  g = (1/ sigma * (2* math.pi)** 1/2) math.exp (-1/2*(x-mi/sigma)**2)                                        ',
#  '  return calculo      ',
#  '  return((1/σ*2math.pi**1/2)e**(-0.5(x-μ/σ)**2))                 ',
#  '',
#  '  f = 1/σ * sqrt(2* pi) * e(-(0.5)*(x − y * z) ** 2)                                     ',
#  '',
#  '  parte2 = math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '  return ((1/(s*math.sqrt(math.pi*2))*math.exp(-0.5*(x-m/s)**2))                                                              ',
#  '  return resposta      ',
#  '  y=(1/σ*(2π)**(1/2))*e**(-0.5*((x-μ)/σ)**2)          ',
#  '  f= (1/(o*math.sqrt(2*math.pi))0**(-0.5*((x - u)/o)**)                               ',
#  '  return fun      ',
#  '  return (1 / (s * math.sqrt(math.pi * 2)) * math.exp (- 0.5 * (x - m / s) ** 2                                                                             ',
#  '  funcao = 1 / σ pow(2 * math.pi)* math.exp * (-0.5 (x - y / σ)**2)                  ',
#  '   ',
#  '  return fun      ',
#  '  f = (1/σ*(2*math.pi)**(1/2))**(-0.5*((x−μ)/σ)**2)                                         ',
#  '  parte2 = math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '',
#  '  return f      ',
#  '  k=a*b ',
#  '',
#  '  a=d*e*f ',
#  '  b=(-0.5)*((x−μ/σ)**2              ',
#  '   ',
#  '',
#  '',
#  '',
#  '  return a      ',
#  '  resultado = 1/(sigma*math.sqrt(2*math.pi))math.exp((-0.5*((x-mi)/sigma)**2))                                              ',
#  '  return y      ',
#  '  return a      ',
#  '  calcula_gaussiana= e**(-0.5*((x-mi)/sigma))**2)/sigma*((2*math.pi)**(1/2))                                               ',
#  '  return f      ',
#  '  return y      ',
#  '  b=math.e**((-0.5)*((x-mi)/sigma)**2)) ',
#  '',
#  '',
#  '',
#  '  import.math       ',
#  '  import.math       ',
#  '  y=(1/(sigma*math.sqrt(2*math.pi)))math.exp(-0.5((x-mi)/sigma)**2)                                      ',
#  '',
#  '  return calcula_gaussiana      ',
#  '  calcula_gaussiana=(1/(σ**1/2*math.pi))math.exp*(-0.5*((x-μ/σ)**2)))                                          ',
#  '  return f      ',
#  '',
#  '  f = 1/σ * sqrt(2* pi) * e(-(0.5)*(x−( y * z)) ** 2)                                    ',
#  '  return (parte1*parte2)      ',
#  '  return ((1/a)*b**c)      ',
#  '  y=((1/σ(2import pi)**1/2)import exp(-0.5(x-μ)/σ))               ',
#  '  return y      ',
#  '  y=(1/sigma*(2*math.pi)**(1/2))*math.exp(-0.5*((x-mi)/sigma)**2))                                                                ',
#  '  return calcula_gaussiana      ',
#  '  f = (1 / (o *((2*3.14)**2))*(e**(-0.5*((x-u)/o)**2)                                                   ',
#  '  from math import sqrt and pi                         ',
#  '  y = (1/(σ*(2π)**(1/2))*e**(-0.5*((x-μ)/σ)**2))             ',
#  '  y = (1/(σ*(2pi)**(1/2))*e**(-0.5*((x-μ)/σ)**2))              ',
#  '  calcula_gaussiana=(1/(σ**0.5*math.pi))math.exp*-0.5*(x-μ/σ)**2                                          ',
#  '',
#  '  math pi       ',
#  '  return f      ',
#  '',
#  '  return form      ',
#  '  return(1/(σ*math.sqrt(2*math.pi))*math.exp**(-0.5*(((x-μ)/σ)**2))                                                                 ',
#  '  if x=0     ',
#  '',
#  '',
#  '  return f      ',
#  '',
#  '  f=(1/σ*(2* math.pi)**(1/2))*math.exp(-0.5*((x-μ)/σ)**2):                                                        ',
#  '  return f      ',
#  '',
#  '  return f      ',
#  '   ',
#  '  a=d*e*f ',
#  '  b=math.e**((-0.5)*((x-mi)/sigma)**2)) ',
#  '  return 1/(σ*math.sqrt(2*math.pi)*10**(-0.5*((x-μ)/σ)**2)                                                        ',
#  '  return f      ',
#  '',
#  '',
#  '',
#  '',
#  '  return f      ',
#  '',
#  '   ',
#  '  return((math.e**(-(1/2)*((x-u)/o)**2)/o*math.sqrt(2*math.pi))                                                             ',
#  '',
#  '  return f      ',
#  '  return gaussiana      ',
#  '  calculo=(1/(sigma*(2*math.pi)**(1/2)))*math.exp(-0.5*((x-mi)/sigma)**2))                                                                        ',
#  '',
#  '  include math            ',
#  '  return calcula_gaussiana      ',
#  '  denominador = sigma * sqrt(2 * pi)           ',
#  '',
#  '  f= (1/(o*math.sqrt(2*math.pi)))exp(-0.5*((x - u)/o)**)                                  ',
#  '  parte2 = math.exp(-0.5*(x-y/z)^2)      ',
#  '  return y      ',
#  '  return f      ',
#  '',
#  '  return y      ',
#  '  return f      ',
#  '  return f      ',
#  '',
#  '  d= a*b*c ',
#  '',
#  '',
#  '  return (1/(s*math.sqrt(math.pi*2))*(math.exp(-0.5*((x-m)/s)**2))                                                                ',
#  '  return y      ',
#  '',
#  '  return f      ',
#  '  return (1 / (s * math.sqrt(math.pi * 2)) * math.exp (- 0.5 * (x - m / s) ** 2)                                                                              ',
#  '',
#  '',
#  '  return form      ',
#  '  import.math       ',
#  '  return f      ',
#  '  return f      ',
#  '',
#  '',
#  '  d= a*b*c ',
#  '  math import sqrt           ',
#  '',
#  '  return G      ',
#  '  b = euler( -0.5 * ((x * mi) / sigma)**2)))                                         ',
#  '',
#  '  return calculo      ',
#  '',
#  '  y=1/σ*(2*import.pi)**(1/2)import.exp(-0.5(x-μ)/σ)**2               ',
#  '  y=(1/(sigma*math.sqrt(2*math.pi)))math.exp(-0.5((x-mi)/sigma)**2)                                      ',
#  '  a=  ',
#  '  y=1/σ*(2*math.pi)**(1/2))*math.exp(-0.5*((x-μ/σ)**2)                         ',
#  '  return r      ',
#  '  return f      ',
#  '  import.math       ',
#  '',
#  '',
#  '  return calculo      ',
#  '  e = math.e**(-0.5*((x-μ/σ)**2)) ',
#  '  return a      ',
#  '  return (f)      ',
#  '  calcula_gaussiana=1/(sigma*((2*math.pi)*(1/2))math.exp(-0.5*((x-mi)/sigma)**2)                                                  ',
#  '  d= a*b*c ',
#  '',
#  '  return f      ',
#  '  return((1/σ*sqrt(2math.pi))*e**(-0.5*(x-μ/σ)**2))                      ',
#  '  return y      ',
#  '  return f      ',
#  '  parte2= math.exp (-0.5 * ((x-mi)/sigma)**2)      ',
#  '  import.math       ',
#  '',
#  '  return a * b      ',
#  '  if x != 0         ',
#  '  return y      ',
#  '',
#  '  f= (1/(o*math.sqrt(2*math.pi)))exp(-0.5*((x - u)/o)**2)                                  ',
#  '',
#  '',
#  '  calcula_gaussiana = (1/(sigma*((2*pi)**(1/2)))                                              ',
#  '  return y      ',
#  '',
#  '  return(1/(σ*math.sqrt(2*math.pi))*math.exp**(-0.5*(((x-μ)/σ)**2))                                                                 ',
#  '  return (1/(σ*2math.pi**1/2))**-0.5((x-μ)/2)**2                  ',
#  '',
#  '  return y      ',
#  '  return gaussiana      ',
#  '  return f      ',
#  '  return cg      ',
#  '  return gauss      ',
#  '',
#  '  c = a * b ',
#  '  y=(1/sigma*(2*math.pi**(1/2)))math.exp(-0.5*((x-mi)/sigma)**2)                                  ',
#  '',
#  '',
#  '  return(1/(σ(2*π)**2)*e**(-0.5((x-μ)/σ)**2)                                          ',
#  '  x = float(input()) a                    ',
#  '   ',
#  '  if sigma = float(inverso):          ',
#  '  return ((1/(s*math.sqrt(math.pi*2))*(math.exp(-0.5*(x-m/s)**2)))                                                                ',
#  '  b=math.exp**((-0.5)*((x-mi)/sigma)**2)) ',
#  '',
#  '  f=(1/σ*(2* math.pi)**(1/2))math.exp(-0.5*((x-μ)/σ)**2)                               ',
#  '  return gau      ',
#  '',
#  '  return f      ',
#  '  return f      ',
#  '  b=(-0.5*((x−μ/σ)**2)             ',
#  '  return y      ',
#  '',
#  '',
#  '  print resultado     ',
#  '  return y      ',
#  '',
#  '  c=(1/σ*2π**(1/2))*e**(-1/2*(x−μ/σ)**2)         ',
#  '  c = (((x - μ)/ σ) ** 2) ',
#  '  gauss= e**(-0.5*((x-mi)/sigma))**2)/sigma*((2*math.pi)**(1/2))                                   ',
#  '  G=1/(sigma*((2*math.pi)math.sqrt)*math.exp(-0.5((x-mi)/sigma)**2)                           ',
#  '  if sigma !=0            ',
#  '  f = (1/(sigma*sqrt(2*pi)))*                           ',
#  '',
#  '  import math *             ',
#  '  parte2 = math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '',
#  '  a=d*e*f ',
#  '  return (1/σ*2math.pi**1/2)**-0.5((x-μ)/2)**2                 ',
#  '  print f     ',
#  '  print resultado     ',
#  '  y=1/(b*(2*math.pi)**1/2))*math.exp(0.5*((x-a)/b)**2)                         ',
#  '  calcula_gaussiana=(1/(σ**1/2*math.pi))math.exp*-0.5*((x-μ/σ)**2)                                          ',
#  '  import.math       ',
#  '  return f      ',
#  '  y=(1/(sigma*(2*math.pi)**(1/2)))math.exp**(-0.5*((x-mi)/sigma)**2)                                    ',
#  '',
#  '',
#  '  return f      ',
#  '  return resultado      ',
#  '  return f      ',
#  '  parte2= math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '',
#  '  math import           ',
#  '  print (calcula_gaussiana)     ',
#  '  g=10**-0.5*((x-mi)/sigma)*2 ',
#  '',
#  '  if sigma == 1/math.srqt(2*math.pi)                                  ',
#  '  if (x == 0 and ):                ',
#  '  retunr form      ',
#  '  return y      ',
#  '  return gauss      ',
#  '',
#  '  return calculo      ',
#  '',
#  '  f = (1/(sigma*sqrt(2*pi)))exp((-0.5((x-mi)/sigma)**2))                             ',
#  '',
#  '  print(y)     ',
#  '',
#  '',
#  '  return f      ',
#  '  y= (1/(sigma*((2*math.pi)**0.5)))*(math.exp(-0.5((x-mi)/sigma)*2))))                                                                   ',
#  '',
#  '  return g      ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '  return f      ',
#  '  return (1 / s * (math.pi * 2) ** 0.5) * math.exp (- 0.5 * (x - m / s) ** 2))                                                                            ',
#  '  return (1/o((2*math.pi)**1/2))*math.e**(-0.5((x-m)/o))**2)                                                          ',
#  '  calcula_gaussiana=(1/(σ**0.5*math.pi))math.exp*(-0.5*(x-μ/σ)**2)                                          ',
#  '  return f      ',
#  '  y=1/(sigma*(2*math.pi)**0.5)math.exp**(-0.5*((x-mi)/sigma)**2)                                ',
#  '',
#  '',
#  '',
#  '  import.math       ',
#  '  f2 = e**((-0.5*(x-mu)/(sigma))**2)  ',
#  '',
#  '',
#  '  z = 1/(o*2 mathpi **0.5)                 ',
#  '',
#  '',
#  '  μ =float(input("valor de mi: ") ',
#  '  return y      ',
#  '   ',
#  '  y=1/(σ*(2*math.pi)**(1/2))math.exp(-0.5((x-μ)/σ)**2)                              ',
#  '  return y      ',
#  '  return  math.exp(-0.5*((x-μ)/σ)**2*(σ*math.sqrt(2)*math.pi)**-1                                                               ',
#  '  return y      ',
#  '  return y      ',
#  '  return y      ',
#  '  if (x == 0 and ):                ',
#  '  c = (1 / (math.sigma)*(2(math.pi))**0.5))*e**(-0.5((x-math.mi)/(math.sigma))**2                                         ',
#  '  return y      ',
#  '  b=(math.e) ',
#  '  parte2 = math.e**(-0.5*((x-mi)/sigma)**2)      ',
#  '   ',
#  '  import .math        ',
#  '  return((e**(-0.5*((x-u)/o)**2))o*sqrt(2*pi))                                ',
#  '  ruturn g        ',
#  '  b=(-0.5)*(x−μ/σ)**2             ',
#  '  return gauss      ',
#  '  g = (1/ sigma * (2* math.pi)** 1/2) math.exp (-1/2*(x-mi/sigma)**2)                                        ',
#  '  def inversa:            ',
#  '  b=2.71**(-0.5*((x-mi)/sigma)**2) ',
#  '  return y      ',
#  '  y = f1*f2 ',
#  '',
#  '  y=(1/sigma*(2*math.pi)**-1))*exp*(-0.5*(x-mi/sigma))**2                            ',
#  '  return f      ',
#  '  parte2 = math.exp(-0.5*(x-y/z)^2)      ',
#  '  return y      ',
#  '  return parte1      ',
#  '  return G      ',
#  '   ',
#  '',
#  '  if (x == 0 and ):                ',
#  '',
#  '  if calcula_gaussiana = 0                      ',
#  '  return calculo      ',
#  '',
#  '  if (sigma == 0 or sigma == - math.sqrt(2*math.pi):                                                  ',
#  '  return G      ',
#  '  return calculo      ',
#  '  return y      ',
#  '',
#  '  return a      ',
#  '  return y      ',
#  '  return (1 / (s * math.sqrt(math.pi * 2)) * math.exp (- 0.5 * (x - m / s) ** 2)                                                                              ',
#  '',
#  '  return equacao      ',
#  '  b=math.e ',
#  '  return  (1/(σ*math.sqrt(2*math.pi))*math.exp((-0.5)*((x-μ)/σ)**2)                                                                 ',
#  '  parte2 = math.exp(-0.5*((a-b)/c)**2)      ',
#  '  f= (1/(σ*math.sqrt(2*math.pi)))exp(-0.5*((x - μ)/σ)**2)                                  ',
#  '  b=(math.e**((-0.5)*((x-mi)/sigma)**2))) ',
#  '  return y      ',
#  '  G=1/(sigma*((2*math.pi math.sqrt)*math.exp(-0.5((x-mi)/sigma)**2)                           ',
#  '',
#  '  y = ((1/sigma*(2*math.pi)**(0.5))math.exp((-0.5)*((x-mi)/sigma)**2)                                     ',
#  '  return f      ',
#  '  parte1 = 1 / (sigma * 2 * math.pi ** 1/2))                                          ',
#  '  return f      ',
#  '  f1 = 1/(\\\\sigma*math.sqrt(2*math.pi)                                   ',
#  '  cg = (1/o*sqrt(2*pi))*(Math.exp(-0.5*(((x-u)/o)**)))                                                  ',
#  '  return calcula_gaussiana      ',
#  '  return y      ',
#  '  y = (1/(sigma*2pi))**(-0.5*(x-mi)/sigma)**2                 ',
#  '  parte2= math.e **( -1/2 * ((x-mi)/sigma) **2)      ',
#  '  return calcula_gaussiana      ',
#  '  b=math.e ',
#  '',
#  '',
#  '  import.math       ',
#  '  g=10**-0.5*((x-mi)/sigma)*2 ',
#  '  return f      ',
#  '  x=d*e*f ',
#  '  return ((1/(σ*(2*π)**(1/2)))*10**(-0.5*((x−μ)/σ)**2)                                            ',
#  '  y=(1/σ*((2*math.pi)**(1/2)))math.exp*(-0.5*((x-μ)/σ)**(1/2))                                ',
#  '',
#  '',
#  '',
#  '  return gaussiana      ',
#  '',
#  '  y=(1/sigma*(2*math.pi)**1/2)**(-o.5*(x-mi/sigma)**2)                                   ',
#  '  return f      ',
#  '',
#  '  return gaussiana      ',
#  '',
#  '  return y      ',
#  '  return f      ',
#  '',
#  '  resultado = 1/(sigma*math.sqrt(2*math.pi))math.exp(float(-0.5)*((x-mi)/sigma)**2)                                              ',
#  '  calcula_gaussiana=(1/(σ**1/2*math.pi))math.exp*-0.5*((x-μ/σ)**2))                                          ',
#  '  return      ',
#  '  if x != 0         ',
#  '',
#  '  return resultado      ',
#  '  return y      ',
#  '  return f      ',
#  '  c=a*b ',
#  '  y = (1/(o * math.sqrt (2 * math. pi)) * math.exp (-0.5 *((x-u)/(o))**2)                                                                       ',
#  '  y = (1/(sigma*(2*math.pi)**(1/2)))*(math.e**((-0.5)*(((x-mi)/sigma)**2))                                                                        ',
#  '',
#  '  return f      ',
#  '',
#  '    ',
#  '  b=2.71**((-0.5)*((x-mi)/sigma)**2)) ',
#  '  return ((1/a)*b**c)      ',
#  '',
#  '  y=1/σ*(2*math.pi)**(1/2))*math.exp(-0.5*((x-μ/σ)**2)                         ',
#  '  g=math.e**(-0.5*((x-y)/z)**2) ',
#  '  c = a*b ',
#  '  z = 1/(o*2 math.pi **0.5)               ',
#  '  return (parte1*parte2)      ',
#  '  return 1/(s*math.sqrt(math.pi*2))*(math.exp(-0.5*((x-m)/s)**2)                                                              ',
#  '',
#  '  return y      ',
#  '',
#  '  return f      ',
#  '   ',
#  '  return f      ',
#  '  import.math       ',
#  '  return resultado      ',
#  '  from math import math.pi as pi                      ',
#  '  l=a*b ',
#  '  z = 1/(o*2 mathpi **0.5)                 ',
#  '  y=(1/c*2*math.pi**1/2)math.exp(-1/2(a-b/c)**2)                          ',
#  '  return f      ',
#  '',
#  '   ',
#  '  return(parte1*parte2)      ',
#  '',
#  '  impot math          ',
#  '  x = float(input()) a                    ',
#  '  c=a*b ',
#  '  μ=float(input("valor de mi: ") ',
#  '',
#  '  import.math       ',
#  '  b = math.exp(-0.5*(((x-μ)/σ)**2)) ',
#  '  f= (1/(o*math.sqrt(2*math.pi)))exp(-0.5*((x - u)/o)**)                                  ',
#  '',
#  '  return resultado      ',
#  '',
#  '  y=((1/σ*(2*import.pi)**1/2)import.exp(-0.5(x-μ)/σ)**2)                 ',
#  '  return calcula_gaussiana      ',
#  '  return parte1      ',
#  '  math.import           ',
#  '',
#  '',
#  '  f2 = e**((-0.5*(x-mu)/(sigma))**2)  ',
#  '  return f      ',
#  '  return y      ',
#  '  f = (1/σ*(2*math.pi)**(1/2))**(-0.5*((x−μ)/σ)**2)                                         ',
#  '  f = 1/σ * sqrt(2* pi) * e(−0.5(x−yz) ** 2)                            ',
#  '',
#  '',
#  '',
#  '  sigma =! 0        ',
#  '  return f      ',
#  '  G=1/(sigma*(2*math.pi)**(1/2))math.exp(-0.5((x-mi)/sigma)**2)                                  ',
#  '  return f      ',
#  '  return y      ',
#  '  return f      ',
#  '  from math import sqrt and pi                         ',
#  '  return f      ',
#  '  sigma =! 0        ',
#  '  impot math          ',
#  '  return a      ',
#  '',
#  '  return resultado      ',
#  '  return equacao      ',
#  '  return calcula_gaussiana      ',
#  '',
#  '  import math.            ',
#  '',
#  '  y=(1/sigma*(math.sqrt(2*math.pi)))*math.exp**((-1/2)*((x-mi)/sigma)**2))                                                                        ',
#  '  return y      ',
#  '  return y      ',
#  '  y=((1/σ(2import.pi)**1/2)import.exp(-0.5(x-μ)/σ))               ',
#  '  cg = (1/o*sqrt(2*pi))*(Math.exp(-0.5*(((x-u)/o)**)                                                  ',
#  '',
#  '',
#  '  y=(1/(sigma*math.sqrt(2*math.pi)))math.exp(-0.5((x-mi)/sigma)**2)                                      ',
#  '  return y      ',
#  '',
#  '  cg = (1/o*sqrt(2*pi))*(Math.exp(-0.5*(((x-u)/o)**))                                                  ',
#  '  import math.exp(x)                ',
#  '  l=a*b ',
#  '  return y      ',
#  '',
#  '  return f      ',
#  '  return a      ',
#  '  f= (1/(z*sqrt(2)*pi)))**(-0.5*((x-y)/z)**2)                      ',
#  '',
#  '  y=(1/sigma*(2*math.pi)**(1/2)) math.exp (-0.5((x-mi)/sigma)**2)                                   ',
#  '  f=1/(c*(2*math.pi)**(1/2))*math.exp*(-0.5*(a-b)/c)**2)                                                      ',
#  '  return f      ',
#  '',
#  '   ',
#  '',
#  '  f = (1/σ*(2* math.pi)**1/2)** (- o.5((x - μ)/ σ)**2)                                    ',
#  '',
#  '  return f      ',
#  '  y=((1/σ2π)exp(-0.5(x-μ)/σ))             ',
#  '  return f      ',
#  '  import.math       ',
#  '  return f      ',
#  '  return f      ',
#  '  parte2 = math.exp(-0.5*((x-mi)/sigma)**2)      ',
#  '',
#  '  l = a * b ',
#  '  c = a*b ',
#  '  return y      ',
#  '  return f      ',
#  '',
#  '',
#  '  return f      ',
#  '  f = (1/(sigma*(2*math.pi)**0.5))math.exp(-0.5((x - mi)/sigma)**2)                                    ',
#  '  c = a*b ',
#  '  return form      ',
#  '',
#  '  return resultado      ',
#  '  return gau      ',
#  '',
#  '',
#  '  d=(a*b)*c ',
#  '  return a      ',
#  '  return (1/(σ*(2*math.pi)**0.5))**(-0.5*((x-μ)/σ)**@)                                                   ',
#  '',
#  '',
#  '  f=(1/σ(2* math.pi)**1/2)math.exp(-0.5*((x-μ)/σ)**2)                            ',
#  '  return calculo      ',
#  '  return a * b      ',
#  '  def x     ',
#  '  B = math.e^(0.5*((x-mi)/sigma)^2) ']

# %%
users_count = df_sintaxe["usuario"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'usuario'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-8ae4441ac9da> in <module>
# ----> 1 users_count = df_sintaxe["usuario"].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'usuario'

# %%
# f, ax = plt.subplots(figsize = (32,20))
# plt.figure(figsize = (640,200))
erros = df_sintaxe["erros"]
users = df_sintaxe["usuario"]
table = pd.crosstab(erros, users)
# plot=sns.heatmap(table,ax=ax, annot=True, cmap="YlGnBu")
# f.savefig("heatmap.png", dpi=200)
table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'erros'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-159f15045aed> in <module>
#       1 # f, ax = plt.subplots(figsize = (32,20))
#       2 # plt.figure(figsize = (640,200))
# ----> 3 erros = df_erros["erros"]
#       4 users = df_erros["usuario"]
#       5 table = pd.crosstab(erros, users)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'erros'

# %% [markdown]
# ## Digite o ID de um usuário para descobrir seus principais erros

# %% [markdown]
# ### Selecione o usuário:

# %%
usuario = "user_086"

# %%
table[usuario]

# %%
errors = df_erros.loc[df_erros["usuario"]==usuario]
errors.loc[:, ["erros","linha","detalhes"]]
