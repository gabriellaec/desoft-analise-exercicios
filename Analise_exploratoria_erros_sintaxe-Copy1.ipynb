# %% [markdown]
# # Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import matplotlib as mpl
mpl.style.use("seaborn")

# %% [markdown]
# # Analisando os erros de sintaxe

# %% [markdown]
# ## Montando o DataFrame com os erros de sintaxe

# %%
nome_exercicio="gaussiana"

# %%
json_results= "exercicios/analise-exercicios/"+ nome_exercicio + "/resultado_detalhado.json"
json_results
# Out:
# 'exercicios/analise-exercicios/gaussiana/resultado_detalhado.json'

# %%
df_exs = pd.read_json(json_results, orient='records')
df_exs = df_exs.rename(columns = {'id':'id','erros':'tipo_do_erro', 'resultado':'passou', 'detalhes':'erro'})

# %%
#df_exs=df_exs.set_index('id')
df_exs.tail(4)
# Out:
#                                    erro  \
# 2313      b = exp((-0,5(((x-m)/s)**2)\n
# 2314                              def x
# 2315       B = math.e0.5*x-mi)/sigma)2)
# 2316
#
#                                            tipo_do_erro  \
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
# 2316  AssertionError: <|><Verificar quando x ou mi é...
#
#                                      id linha  passou
# 2313  ch3_2020_03_04_20_08_39_273348.py     5   False
# 2314  ch3_2019_09_11_23_12_24_127271.py     1   False
# 2315  ch3_2020_03_04_19_49_40_592877.py     4   False
# 2316  ch3_2020_09_04_16_47_36_060892.py         False

# %%
df_erros=df_exs[df_exs['passou']==False]

df_erros.head()
# Out:
#                                                 erro  \
# 1      y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/...
# 2
# 3                                               if x
# 4      y=1/sigma*2*math.pi)**0.5)math.e**-0.5*x-m...
# 5
#
#                                   tipo_do_erro  \
# 1                  SyntaxError: invalid syntax
# 2  TypeError: \'float\' object is not callable
# 3                  SyntaxError: invalid syntax
# 4                  SyntaxError: invalid syntax
# 5  TypeError: \'float\' object is not callable
#
#                                   id linha  passou
# 1  ch3_2019_08_13_16_52_03_378932.py     3   False
# 2  ch3_2020_03_09_19_11_49_185208.py         False
# 3  ch3_2020_02_28_17_44_32_436097.py     3   False
# 4  ch3_2019_03_01_12_59_50_648548.py     3   False
# 5  ch3_2020_02_20_00_11_13_695953.py         False

# %%
df_sintaxe = df_erros[df_erros['tipo_do_erro'].str.contains("SyntaxError", na=False)]
df_sintaxe
# Out:
#                                                    erro  \
# 1         y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/...
# 3                                                  if x
# 4         y=1/sigma*2*math.pi)**0.5)math.e**-0.5*x-m...
# 7                       print(calcula_gaussiana(0,0,1))
# 11                                           return 0\n
# 17                         from import math e, sqrt, pi
# 23                                   Import numpy as np
# 24                  print calcula_gaussiana(10, 12, 11)
# 26        f=1/σ*2* math.pi)**1/2))*math.exp-0.5*x-μ)...
# 32       g=(1/sigma*(2pi)**(-1/2)*e**(0,5((x-mi)/sig...
# 34        f(x,μ,σ) =(1/(σ*((2*math.pi)**0.5))**(-0.5...
# 36                                                   ')
# 37                                                   ')
# 38        calculo = (1/(sigma*(2*math.pi)**(1/2))*ma...
# 39        y = (1/sigma*(2*math.pi)**(1/2))*math.e**(...
# 41        resultado = (1/(z*sqrt(2*math.pi))**((-0.5...
# 42                      def calcula_gaussiana(x,μ,σ):\n
# 48                                            a = y * z
# 50                     b=2,71**(-0.5*((x-mi)/sigma)**2)
# 57        y = (1/sigma*(2*math.pi)**(0.5)*math.exp((...
# 63                      print(calcula_gaussiana(0,0,1))
# 65                                            f = a * b
# 72        equacao = (1 / (sigma((2*math.pi)**(1/2)))...
# 74                                if x,mi,sigma!=0,0,0:
# 78                                                   ')
# 81        f= (1/sig*math.sqrt(2*math.pi))*(math.exp(...
# 86                                     math import sqrt
# 95                                         1/sqrt2*pi))
# 97                                                   1)
# 98        f= 1/(sigma*math.sqrt(2*math.pi))*math.e**...
# ...                                                 ...
# 2236                                        import.math
# 2237      f=(1/(sig*(math.sqrt(2*(math.pi))))**(-(1/...
# 2238      f = (1/(o*((2*math.pi)**1/2))*math.e**(-0....
# 2244             parte2 = math.exp-0.5*x-mi)/sigma)**2)
# 2247                             1/math.sqrt2*math.pi))
# 2251                                          l = a * b
# 2256                                            c = a*b
# 2259      y = float((1/(sigma*(2 * math.pi)**(1/2)))...
# 2262  \tf=(1/(σ*(2*math.pi)**(1/2))*math.exp(-0.5*((...
# 2267                                       5x−yz) ** 2)
# 2271                       from import math e, sqrt, pi
# 2273      f = (1/sig*math.sqrt(2*math.pi))*(math.exp...
# 2275      f = 1/sigma*2*math.pi)**0.5))math.exp-0.5x...
# 2276                                            c = a*b
# 2282      form = (1/ (sigma((2*math.pi)**(1/2)))) * ...
# 2283                                         \\sigma) :
# 2285      resultado = (1 / (σ * sqrt(2 * math.pi)) *...
# 2292      gau = (math.e ** (-0.5 * ( (x - μ) /  σ  )...
# 2293                  def calcula_gaussiana(x,mi,sigma)
# 2294                          71**-1/2*x−mi)/sigma)**2)
# 2296                                           d=a*b)*c
# 2297      a=(1/(sigma*((2*math.pi)**(1/2))*math.exp)...
# 2299                   def calcula_gausssiana(x,μ,σ):\n
# 2305     f = (1/(sigma*math.sqrt(2*math.pi)))*math.e...
# 2307                       5\\frac{x-\\mu}{\\sigma})2)}
# 2308      f=1/σ2* math.pi)**1/2)math.exp-0.5*x-μ)/σ)...
# 2309      calculo = (1/(σ*math.sqrt(2*math.pi))**((-...
# 2313                      b = exp((-0,5(((x-m)/s)**2)\n
# 2314                                              def x
# 2315                       B = math.e0.5*x-mi)/sigma)2)
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id                              linha  \
# 1     ch3_2019_08_13_16_52_03_378932.py                                  3
# 3     ch3_2020_02_28_17_44_32_436097.py                                  3
# 4     ch3_2019_03_01_12_59_50_648548.py                                  3
# 7     ch3_2020_03_18_23_48_15_310305.py                                 10
# 11    ch3_2019_03_30_20_28_09_678811.py                                  5
# 17    ch3_2020_03_09_13_49_29_497280.py                                  1
# 23    ch3_2020_09_21_18_42_03_389570.py                                  1
# 24    ch3_2020_08_04_15_47_57_054802.py                                  5
# 26    ch3_2019_08_12_17_09_58_433774.py                                  3
# 32    ch3_2020_09_29_19_01_20_963868.py                                  2
# 34    ch3_2019_06_05_01_20_09_945293.py                                  3
# 36    ch3_2020_03_25_19_08_34_352508.py                                  2
# 37    ch3_2020_03_02_18_45_49_216760.py                                  2
# 38    ch3_2020_03_09_13_38_03_494630.py                                  3
# 39    ch3_2020_03_03_10_10_14_055491.py                                  3
# 41    ch3_2019_03_14_19_31_10_022969.py                                  3
# 42    ch3_2020_09_23_20_30_53_343376.py                                  2
# 48    ch3_2020_03_23_14_55_07_251707.py                                  5
# 50    ch3_2020_03_31_18_21_08_348102.py                                  4
# 57    ch3_2019_03_11_21_58_43_396919.py                                  3
# 63    ch3_2020_03_03_17_29_08_273899.py                                 10
# 65    ch3_2020_03_23_14_54_35_351935.py                                  5
# 72    ch3_2020_09_09_12_11_29_735802.py                                  3
# 74    ch3_2019_03_09_17_39_36_402103.py                                  3
# 78    ch3_2019_08_13_19_43_22_340603.py                                  4
# 81    ch3_2020_04_10_20_37_39_895697.py                                  4
# 86    ch3_2019_08_16_19_15_13_019576.py                                  1
# 95    ch3_2020_03_02_21_35_28_782122.py  raceback (most recent call last):
# 97    ch3_2020_03_09_14_03_07_787857.py  raceback (most recent call last):
# 98    ch3_2020_03_09_19_09_40_205386.py                                  3
# ...                                 ...                                ...
# 2236  ch3_2019_03_12_21_10_44_924213.py                                  1
# 2237  ch3_2019_05_29_20_31_32_260220.py                                  4
# 2238  ch3_2020_09_08_17_30_19_635442.py                                  3
# 2244  ch3_2020_03_02_19_45_08_686566.py                                  5
# 2247  ch3_2020_04_06_18_54_42_307975.py  raceback (most recent call last):
# 2251  ch3_2020_03_23_14_53_58_631703.py                                  5
# 2256  ch3_2020_03_04_20_07_24_339955.py                                  6
# 2259  ch3_2019_08_26_20_23_52_343763.py                                  3
# 2262  ch3_2019_08_13_18_22_43_129570.py                                  3
# 2267  ch3_2020_09_09_12_15_02_756573.py  raceback (most recent call last):
# 2271  ch3_2020_03_09_13_48_29_232954.py                                  1
# 2273  ch3_2020_04_10_20_31_14_492924.py                                  4
# 2275  ch3_2019_08_14_13_30_47_108204.py                                  5
# 2276  ch3_2020_03_04_20_07_43_567598.py                                  6
# 2282  ch3_2020_09_09_12_04_43_548755.py                                  3
# 2283  ch3_2020_09_14_14_03_25_072072.py  raceback (most recent call last):
# 2285  ch3_2020_08_31_18_44_55_201192.py                                  3
# 2292  ch3_2020_09_09_20_18_58_431532.py                                  3
# 2293  ch3_2020_09_09_20_41_11_770857.py                                  3
# 2294  ch3_2020_03_09_20_28_58_798238.py  raceback (most recent call last):
# 2296  ch3_2020_09_09_14_29_37_403356.py                                  6
# 2297  ch3_2019_03_29_14_07_34_917203.py                                  3
# 2299  ch3_2019_03_07_18_57_42_939362.py                                  3
# 2305  ch3_2019_08_21_17_54_12_801185.py                                  3
# 2307  ch3_2020_03_23_10_14_53_153109.py  raceback (most recent call last):
# 2308  ch3_2019_08_12_17_07_36_036992.py                                  3
# 2309  ch3_2019_03_13_20_36_46_064099.py                                  3
# 2313  ch3_2020_03_04_20_08_39_273348.py                                  5
# 2314  ch3_2019_09_11_23_12_24_127271.py                                  1
# 2315  ch3_2020_03_04_19_49_40_592877.py                                  4
#
#       passou
# 1      False
# 3      False
# 4      False
# 7      False
# 11     False
# 17     False
# 23     False
# 24     False
# 26     False
# 32     False
# 34     False
# 36     False
# 37     False
# 38     False
# 39     False
# 41     False
# 42     False
# 48     False
# 50     False
# 57     False
# 63     False
# 65     False
# 72     False
# 74     False
# 78     False
# 81     False
# 86     False
# 95     False
# 97     False
# 98     False
# ...      ...
# 2236   False
# 2237   False
# 2238   False
# 2244   False
# 2247   False
# 2251   False
# 2256   False
# 2259   False
# 2262   False
# 2267   False
# 2271   False
# 2273   False
# 2275   False
# 2276   False
# 2282   False
# 2283   False
# 2285   False
# 2292   False
# 2293   False
# 2294   False
# 2296   False
# 2297   False
# 2299   False
# 2305   False
# 2307   False
# 2308   False
# 2309   False
# 2313   False
# 2314   False
# 2315   False
#
# [676 rows x 5 columns]

# %%
df_sintaxe["possivel_solucao"]="--"

# %%
df_sintaxe.head()
# Out:
#                                                  erro  \
# 1       y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/...
# 3                                                if x
# 4       y=1/sigma*2*math.pi)**0.5)math.e**-0.5*x-m...
# 7                     print(calcula_gaussiana(0,0,1))
# 11                                         return 0\n
#
#                                  tipo_do_erro  \
# 1                 SyntaxError: invalid syntax
# 3                 SyntaxError: invalid syntax
# 4                 SyntaxError: invalid syntax
# 7                 SyntaxError: invalid syntax
# 11  SyntaxError: unexpected EOF while parsing
#
#                                    id linha  passou possivel_solucao
# 1   ch3_2019_08_13_16_52_03_378932.py     3   False               --
# 3   ch3_2020_02_28_17_44_32_436097.py     3   False               --
# 4   ch3_2019_03_01_12_59_50_648548.py     3   False               --
# 7   ch3_2020_03_18_23_48_15_310305.py    10   False               --
# 11  ch3_2019_03_30_20_28_09_678811.py     5   False               --

# %% [markdown]
# ## Adicionando os IDs dos usuários ao dataframe

# %%
import os

def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.join(root, name))
    return r

# %%
dir = r"C:\Users\gabic\Documents\NINJA_DeSoft\submissoes_servidor\backup"
files = list_files(dir)

# %%
lista_files = []
for f in files:
    f = f[65:]
    f.replace("//","/")
    lista_files.append(f)
    
lista_files= lista_files[1:]

# %%
df_sintaxe["usuario"]="--"
for ind in df_sintaxe.index: 
        for l in lista_files:
            user = l[0:8]
            ex = l[9:]
            if ex == df_sintaxe["id"][ind]:
                df_sintaxe["usuario"][ind] = user
#                 print(user)
#                 print(ex)

# %%
df_sintaxe
# Out:
#                                                detalhes  \
# 1     [('line 3\n    y=((1/σ*(2import.pi)**1/2)impor...
# 3     [('line 3\n    if x\n       ^\nSyntaxError: in...
# 4     [('line 3\n    y=1/(sigma*(2*math.pi)**0.5)mat...
# 7      [1))\n        ^\nSyntaxError: invalid syntax\n']
# 11    [ line 6\n    return (1/sigma*math.sqrt(2*math...
# 17    [ pi\n              ^\nSyntaxError: invalid sy...
# 23    [('line 1\n    Import numpy as np\n           ...
# 24    [ 11)\n                          ^\nSyntaxErro...
# 26    [('line 3\n    f=(1/σ*(2* math.pi)**(1/2))*mat...
# 32    [5((x-mi)/sigma)*2)\n                  ^\nSynt...
# 34     [σ)\n         ^\nSyntaxError: invalid syntax\n']
# 36    [ line 2\nSyntaxError: can\'t assign to functi...
# 37    [ line 2\nSyntaxError: can\'t assign to functi...
# 38    [('line 4\n    return calculo\n         ^\nSyn...
# 39    [('line 4\n    return y\n         ^\nSyntaxErr...
# 41    [('line 4\n    return resultado\n         ^\nS...
# 42    [ line 3\n    return  (1/(σ*math.sqrt(2*math.p...
# 48    [('line 5\n    a = y * z\n    ^\nSyntaxError: ...
# 50    [71**(-0.5*((x-mi)/sigma)**2)\n    ^\nSyntaxEr...
# 57    [('line 4\n    return y\n         ^\nSyntaxErr...
# 63     [1))\n        ^\nSyntaxError: invalid syntax\n']
# 65    [('line 5\n    f = a * b\n    ^\nSyntaxError: ...
# 72    [ line 4\n    #return equacao\n               ...
# 74      [0:\n        ^\nSyntaxError: invalid syntax\n']
# 78    [ line 4\nSyntaxError: \'return\' outside func...
# 81    [('line 5\n    return f\n         ^\nSyntaxErr...
# 86    [('line 1\n    math import sqrt\n             ...
# 95    [ 1/sqrt(2*pi))\n                             ...
# 97    [ 1)\n                                   ^\nSy...
# 98    [('line 4\n    return f\n         ^\nSyntaxErr...
# ...                                                 ...
# 2236  [('line 1\n    import.math\n          ^\nSynta...
# 2237  [('line 5\n    return f\n         ^\nSyntaxErr...
# 2238  [('line 4\n    return f\n         ^\nSyntaxErr...
# 2244  [('line 5\n    parte2 = math.exp(-0.5*((x-mi)/...
# 2247  [1/math.sqrt(2*math.pi))\n                    ...
# 2251  [('line 5\n    l = a * b\n    ^\nSyntaxError: ...
# 2256  [('line 6\n    c = a*b\n    ^\nSyntaxError: in...
# 2259  [('line 4\n    return y\n         ^\nSyntaxErr...
# 2262  [('line 4\n    return f\n         ^\nSyntaxErr...
# 2267  [5(x−yz) ** 2)\n                              ...
# 2271  [ pi\n              ^\nSyntaxError: invalid sy...
# 2273  [('line 5\n    return f\n         ^\nSyntaxErr...
# 2275  [('line 5\n    f = (1/(sigma*(2*math.pi)**0.5)...
# 2276  [('line 6\n    c = a*b\n    ^\nSyntaxError: in...
# 2282  [('line 4\n    return form\n         ^\nSyntax...
# 2283  [\\sigma) :\n                                 ...
# 2285  [('line 4\n    return resultado\n         ^\nS...
# 2292  [('line 4\n    return gau\n         ^\nSyntaxE...
# 2293  [sigma)\n                                    ^...
# 2294  [71**(-1/2*((x−mi)/sigma)**2)\n               ...
# 2296  [('line 6\n    d=(a*b)*c\n    ^\nSyntaxError: ...
# 2297  [('line 4\n    return a\n         ^\nSyntaxErr...
# 2299  [('line 4\n    return (1/(σ*(2*math.pi)**0.5))...
# 2305  [5)*((x-mi)/sigma)**2))\n                     ...
# 2307  [5(\\frac{x-\\mu}{\\sigma})^2)}\n             ...
# 2308  [('line 3\n    f=(1/σ(2* math.pi)**1/2)math.ex...
# 2309  [('line 4\n    return calculo\n         ^\nSyn...
# 2313  [('line 6\n    return a * b\n         ^\nSynta...
# 2314  [('line 1\n    def x\n        ^\nSyntaxError: ...
# 2315  [('line 4\n    B = math.e^(0.5*((x-mi)/sigma)^...
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id                              linha  \
# 1     ch3_2019_08_13_16_52_03_378932.py                                  3
# 3     ch3_2020_02_28_17_44_32_436097.py                                  3
# 4     ch3_2019_03_01_12_59_50_648548.py                                  3
# 7     ch3_2020_03_18_23_48_15_310305.py                                 10
# 11    ch3_2019_03_30_20_28_09_678811.py                                  5
# 17    ch3_2020_03_09_13_49_29_497280.py                                  1
# 23    ch3_2020_09_21_18_42_03_389570.py                                  1
# 24    ch3_2020_08_04_15_47_57_054802.py                                  5
# 26    ch3_2019_08_12_17_09_58_433774.py                                  3
# 32    ch3_2020_09_29_19_01_20_963868.py                                  2
# 34    ch3_2019_06_05_01_20_09_945293.py                                  3
# 36    ch3_2020_03_25_19_08_34_352508.py                                  2
# 37    ch3_2020_03_02_18_45_49_216760.py                                  2
# 38    ch3_2020_03_09_13_38_03_494630.py                                  3
# 39    ch3_2020_03_03_10_10_14_055491.py                                  3
# 41    ch3_2019_03_14_19_31_10_022969.py                                  3
# 42    ch3_2020_09_23_20_30_53_343376.py                                  2
# 48    ch3_2020_03_23_14_55_07_251707.py                                  5
# 50    ch3_2020_03_31_18_21_08_348102.py                                  4
# 57    ch3_2019_03_11_21_58_43_396919.py                                  3
# 63    ch3_2020_03_03_17_29_08_273899.py                                 10
# 65    ch3_2020_03_23_14_54_35_351935.py                                  5
# 72    ch3_2020_09_09_12_11_29_735802.py                                  3
# 74    ch3_2019_03_09_17_39_36_402103.py                                  3
# 78    ch3_2019_08_13_19_43_22_340603.py                                  4
# 81    ch3_2020_04_10_20_37_39_895697.py                                  4
# 86    ch3_2019_08_16_19_15_13_019576.py                                  1
# 95    ch3_2020_03_02_21_35_28_782122.py  raceback (most recent call last):
# 97    ch3_2020_03_09_14_03_07_787857.py  raceback (most recent call last):
# 98    ch3_2020_03_09_19_09_40_205386.py                                  3
# ...                                 ...                                ...
# 2236  ch3_2019_03_12_21_10_44_924213.py                                  1
# 2237  ch3_2019_05_29_20_31_32_260220.py                                  4
# 2238  ch3_2020_09_08_17_30_19_635442.py                                  3
# 2244  ch3_2020_03_02_19_45_08_686566.py                                  5
# 2247  ch3_2020_04_06_18_54_42_307975.py  raceback (most recent call last):
# 2251  ch3_2020_03_23_14_53_58_631703.py                                  5
# 2256  ch3_2020_03_04_20_07_24_339955.py                                  6
# 2259  ch3_2019_08_26_20_23_52_343763.py                                  3
# 2262  ch3_2019_08_13_18_22_43_129570.py                                  3
# 2267  ch3_2020_09_09_12_15_02_756573.py  raceback (most recent call last):
# 2271  ch3_2020_03_09_13_48_29_232954.py                                  1
# 2273  ch3_2020_04_10_20_31_14_492924.py                                  4
# 2275  ch3_2019_08_14_13_30_47_108204.py                                  5
# 2276  ch3_2020_03_04_20_07_43_567598.py                                  6
# 2282  ch3_2020_09_09_12_04_43_548755.py                                  3
# 2283  ch3_2020_09_14_14_03_25_072072.py  raceback (most recent call last):
# 2285  ch3_2020_08_31_18_44_55_201192.py                                  3
# 2292  ch3_2020_09_09_20_18_58_431532.py                                  3
# 2293  ch3_2020_09_09_20_41_11_770857.py                                  3
# 2294  ch3_2020_03_09_20_28_58_798238.py  raceback (most recent call last):
# 2296  ch3_2020_09_09_14_29_37_403356.py                                  6
# 2297  ch3_2019_03_29_14_07_34_917203.py                                  3
# 2299  ch3_2019_03_07_18_57_42_939362.py                                  3
# 2305  ch3_2019_08_21_17_54_12_801185.py                                  3
# 2307  ch3_2020_03_23_10_14_53_153109.py  raceback (most recent call last):
# 2308  ch3_2019_08_12_17_07_36_036992.py                                  3
# 2309  ch3_2019_03_13_20_36_46_064099.py                                  3
# 2313  ch3_2020_03_04_20_08_39_273348.py                                  5
# 2314  ch3_2019_09_11_23_12_24_127271.py                                  1
# 2315  ch3_2020_03_04_19_49_40_592877.py                                  4
#
#       passou
# 1      False
# 3      False
# 4      False
# 7      False
# 11     False
# 17     False
# 23     False
# 24     False
# 26     False
# 32     False
# 34     False
# 36     False
# 37     False
# 38     False
# 39     False
# 41     False
# 42     False
# 48     False
# 50     False
# 57     False
# 63     False
# 65     False
# 72     False
# 74     False
# 78     False
# 81     False
# 86     False
# 95     False
# 97     False
# 98     False
# ...      ...
# 2236   False
# 2237   False
# 2238   False
# 2244   False
# 2247   False
# 2251   False
# 2256   False
# 2259   False
# 2262   False
# 2267   False
# 2271   False
# 2273   False
# 2275   False
# 2276   False
# 2282   False
# 2283   False
# 2285   False
# 2292   False
# 2293   False
# 2294   False
# 2296   False
# 2297   False
# 2299   False
# 2305   False
# 2307   False
# 2308   False
# 2309   False
# 2313   False
# 2314   False
# 2315   False
#
# [676 rows x 5 columns]

# %% [markdown]
# # Analisando e classificando os erros

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
df_sintaxe.dtypes
# Out:
# erro                object
# tipo_do_erro        object
# id                  object
# linha               object
# passou                bool
# possivel_solucao    object
# dtype: object

# %%
df_sintaxe["erro"][1]
# Out:
# '    y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/σ)**2)'

# %%
for ind in df_sintaxe.index: 
    line = str( df_sintaxe["linha"][ind] )
    det = df_sintaxe["detalhes"][ind]
#     print(det)
#     det=str(det)
#     df_sintaxe["linha"][ind]=line
#     line=str(line)
    if "(" in line:
        line=line.replace("(","")  
        df_sintaxe["linha"][ind]=line

#     error=df_sintaxe["erros"][ind]
    if len(line)>4:
        df_sintaxe["linha"][ind]= "--"
        
        
#     print(det)
    for x in det:
#         print(x)
        x=x.replace("\\n","")
        x=x.replace("   ^","")
        

        if "SyntaxError" in x:
            detail=x[x.index("SyntaxError:") + len("SyntaxError:"):]
            detail=detail.replace("'", "")
            detail=detail.replace(")", "")
            df_sintaxe["detalhes"][ind]=detail
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'detalhes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-a6a10216a55e> in <module>
#       1 for ind in df_sintaxe.index:
#       2     line = str( df_sintaxe["linha"][ind] )
# ----> 3     det = df_sintaxe["detalhes"][ind]
#       4 #     print(det)
#       5 #     det=str(det)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'detalhes'

# %%
df_sintaxe
# Out:
#                                                    erro  \
# 1         y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/...
# 3                                                  if x
# 4         y=1/sigma*2*math.pi)**0.5)math.e**-0.5*x-m...
# 7                       print(calcula_gaussiana(0,0,1))
# 11                                           return 0\n
# 17                         from import math e, sqrt, pi
# 23                                   Import numpy as np
# 24                  print calcula_gaussiana(10, 12, 11)
# 26        f=1/σ*2* math.pi)**1/2))*math.exp-0.5*x-μ)...
# 32       g=(1/sigma*(2pi)**(-1/2)*e**(0,5((x-mi)/sig...
# 34        f(x,μ,σ) =(1/(σ*((2*math.pi)**0.5))**(-0.5...
# 36                                                   ')
# 37                                                   ')
# 38        calculo = (1/(sigma*(2*math.pi)**(1/2))*ma...
# 39        y = (1/sigma*(2*math.pi)**(1/2))*math.e**(...
# 41        resultado = (1/(z*sqrt(2*math.pi))**((-0.5...
# 42                      def calcula_gaussiana(x,μ,σ):\n
# 48                                            a = y * z
# 50                     b=2,71**(-0.5*((x-mi)/sigma)**2)
# 57        y = (1/sigma*(2*math.pi)**(0.5)*math.exp((...
# 63                      print(calcula_gaussiana(0,0,1))
# 65                                            f = a * b
# 72        equacao = (1 / (sigma((2*math.pi)**(1/2)))...
# 74                                if x,mi,sigma!=0,0,0:
# 78                                                   ')
# 81        f= (1/sig*math.sqrt(2*math.pi))*(math.exp(...
# 86                                     math import sqrt
# 95                                         1/sqrt2*pi))
# 97                                                   1)
# 98        f= 1/(sigma*math.sqrt(2*math.pi))*math.e**...
# ...                                                 ...
# 2236                                        import.math
# 2237      f=(1/(sig*(math.sqrt(2*(math.pi))))**(-(1/...
# 2238      f = (1/(o*((2*math.pi)**1/2))*math.e**(-0....
# 2244             parte2 = math.exp-0.5*x-mi)/sigma)**2)
# 2247                             1/math.sqrt2*math.pi))
# 2251                                          l = a * b
# 2256                                            c = a*b
# 2259      y = float((1/(sigma*(2 * math.pi)**(1/2)))...
# 2262  \tf=(1/(σ*(2*math.pi)**(1/2))*math.exp(-0.5*((...
# 2267                                       5x−yz) ** 2)
# 2271                       from import math e, sqrt, pi
# 2273      f = (1/sig*math.sqrt(2*math.pi))*(math.exp...
# 2275      f = 1/sigma*2*math.pi)**0.5))math.exp-0.5x...
# 2276                                            c = a*b
# 2282      form = (1/ (sigma((2*math.pi)**(1/2)))) * ...
# 2283                                         \\sigma) :
# 2285      resultado = (1 / (σ * sqrt(2 * math.pi)) *...
# 2292      gau = (math.e ** (-0.5 * ( (x - μ) /  σ  )...
# 2293                  def calcula_gaussiana(x,mi,sigma)
# 2294                          71**-1/2*x−mi)/sigma)**2)
# 2296                                           d=a*b)*c
# 2297      a=(1/(sigma*((2*math.pi)**(1/2))*math.exp)...
# 2299                   def calcula_gausssiana(x,μ,σ):\n
# 2305     f = (1/(sigma*math.sqrt(2*math.pi)))*math.e...
# 2307                       5\\frac{x-\\mu}{\\sigma})2)}
# 2308      f=1/σ2* math.pi)**1/2)math.exp-0.5*x-μ)/σ)...
# 2309      calculo = (1/(σ*math.sqrt(2*math.pi))**((-...
# 2313                      b = exp((-0,5(((x-m)/s)**2)\n
# 2314                                              def x
# 2315                       B = math.e0.5*x-mi)/sigma)2)
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id                              linha  \
# 1     ch3_2019_08_13_16_52_03_378932.py                                  3
# 3     ch3_2020_02_28_17_44_32_436097.py                                  3
# 4     ch3_2019_03_01_12_59_50_648548.py                                  3
# 7     ch3_2020_03_18_23_48_15_310305.py                                 10
# 11    ch3_2019_03_30_20_28_09_678811.py                                  5
# 17    ch3_2020_03_09_13_49_29_497280.py                                  1
# 23    ch3_2020_09_21_18_42_03_389570.py                                  1
# 24    ch3_2020_08_04_15_47_57_054802.py                                  5
# 26    ch3_2019_08_12_17_09_58_433774.py                                  3
# 32    ch3_2020_09_29_19_01_20_963868.py                                  2
# 34    ch3_2019_06_05_01_20_09_945293.py                                  3
# 36    ch3_2020_03_25_19_08_34_352508.py                                  2
# 37    ch3_2020_03_02_18_45_49_216760.py                                  2
# 38    ch3_2020_03_09_13_38_03_494630.py                                  3
# 39    ch3_2020_03_03_10_10_14_055491.py                                  3
# 41    ch3_2019_03_14_19_31_10_022969.py                                  3
# 42    ch3_2020_09_23_20_30_53_343376.py                                  2
# 48    ch3_2020_03_23_14_55_07_251707.py                                  5
# 50    ch3_2020_03_31_18_21_08_348102.py                                  4
# 57    ch3_2019_03_11_21_58_43_396919.py                                  3
# 63    ch3_2020_03_03_17_29_08_273899.py                                 10
# 65    ch3_2020_03_23_14_54_35_351935.py                                  5
# 72    ch3_2020_09_09_12_11_29_735802.py                                  3
# 74    ch3_2019_03_09_17_39_36_402103.py                                  3
# 78    ch3_2019_08_13_19_43_22_340603.py                                  4
# 81    ch3_2020_04_10_20_37_39_895697.py                                  4
# 86    ch3_2019_08_16_19_15_13_019576.py                                  1
# 95    ch3_2020_03_02_21_35_28_782122.py  raceback (most recent call last):
# 97    ch3_2020_03_09_14_03_07_787857.py  raceback (most recent call last):
# 98    ch3_2020_03_09_19_09_40_205386.py                                  3
# ...                                 ...                                ...
# 2236  ch3_2019_03_12_21_10_44_924213.py                                  1
# 2237  ch3_2019_05_29_20_31_32_260220.py                                  4
# 2238  ch3_2020_09_08_17_30_19_635442.py                                  3
# 2244  ch3_2020_03_02_19_45_08_686566.py                                  5
# 2247  ch3_2020_04_06_18_54_42_307975.py  raceback (most recent call last):
# 2251  ch3_2020_03_23_14_53_58_631703.py                                  5
# 2256  ch3_2020_03_04_20_07_24_339955.py                                  6
# 2259  ch3_2019_08_26_20_23_52_343763.py                                  3
# 2262  ch3_2019_08_13_18_22_43_129570.py                                  3
# 2267  ch3_2020_09_09_12_15_02_756573.py  raceback (most recent call last):
# 2271  ch3_2020_03_09_13_48_29_232954.py                                  1
# 2273  ch3_2020_04_10_20_31_14_492924.py                                  4
# 2275  ch3_2019_08_14_13_30_47_108204.py                                  5
# 2276  ch3_2020_03_04_20_07_43_567598.py                                  6
# 2282  ch3_2020_09_09_12_04_43_548755.py                                  3
# 2283  ch3_2020_09_14_14_03_25_072072.py  raceback (most recent call last):
# 2285  ch3_2020_08_31_18_44_55_201192.py                                  3
# 2292  ch3_2020_09_09_20_18_58_431532.py                                  3
# 2293  ch3_2020_09_09_20_41_11_770857.py                                  3
# 2294  ch3_2020_03_09_20_28_58_798238.py  raceback (most recent call last):
# 2296  ch3_2020_09_09_14_29_37_403356.py                                  6
# 2297  ch3_2019_03_29_14_07_34_917203.py                                  3
# 2299  ch3_2019_03_07_18_57_42_939362.py                                  3
# 2305  ch3_2019_08_21_17_54_12_801185.py                                  3
# 2307  ch3_2020_03_23_10_14_53_153109.py  raceback (most recent call last):
# 2308  ch3_2019_08_12_17_07_36_036992.py                                  3
# 2309  ch3_2019_03_13_20_36_46_064099.py                                  3
# 2313  ch3_2020_03_04_20_08_39_273348.py                                  5
# 2314  ch3_2019_09_11_23_12_24_127271.py                                  1
# 2315  ch3_2020_03_04_19_49_40_592877.py                                  4
#
#       passou possivel_solucao
# 1      False               --
# 3      False               --
# 4      False               --
# 7      False               --
# 11     False               --
# 17     False               --
# 23     False               --
# 24     False               --
# 26     False               --
# 32     False               --
# 34     False               --
# 36     False               --
# 37     False               --
# 38     False               --
# 39     False               --
# 41     False               --
# 42     False               --
# 48     False               --
# 50     False               --
# 57     False               --
# 63     False               --
# 65     False               --
# 72     False               --
# 74     False               --
# 78     False               --
# 81     False               --
# 86     False               --
# 95     False               --
# 97     False               --
# 98     False               --
# ...      ...              ...
# 2236   False               --
# 2237   False               --
# 2238   False               --
# 2244   False               --
# 2247   False               --
# 2251   False               --
# 2256   False               --
# 2259   False               --
# 2262   False               --
# 2267   False               --
# 2271   False               --
# 2273   False               --
# 2275   False               --
# 2276   False               --
# 2282   False               --
# 2283   False               --
# 2285   False               --
# 2292   False               --
# 2293   False               --
# 2294   False               --
# 2296   False               --
# 2297   False               --
# 2299   False               --
# 2305   False               --
# 2307   False               --
# 2308   False               --
# 2309   False               --
# 2313   False               --
# 2314   False               --
# 2315   False               --
#
# [676 rows x 6 columns]

# %%
erro_import=0
erro_antes_do_return=0
erro_parenteses=0
erro_potencia=0
erro_if=0
erro_while=0
erro_for=0
erro_def=0
erro_pi=0
erro_vezes=0

# %%
lista_tipos_erros=[]
for ind in df_sintaxe.index: 
    sol='--'
    erro = df_sintaxe["erro"][ind]
    erro=str(erro)
    
#     if "return" in erro and len(erro)<30:
#         sol="Verifique a linha antes do return"
#         erro_antes_do_return+=1
    if "import" in erro or "Import" in erro:
        sol="Verifique a maneira com que está realizando o import"
        erro_import+=1
    if "(" in erro:
        abre_parenteses=erro.count('(')
        fecha_parenteses=erro.count(')')
        if abre_parenteses>fecha_parenteses:
            sol="Faltou fechar um parênteses"
        elif abre_parenteses<fecha_parenteses:
            sol="Faltou abrir um parênteses"
        erro_parenteses+=1
        
    if "^" in erro:
        sol="Potência em Python é: **"
        erro_potencia+=1
        
    if "if" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'if'"
        erro_if+=1
        
    if "while" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'while'"
        erro_while+=1
        
    if "for" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'for'"
        erro_for+=1
        
    if "def" in erro and ":" not in erro:
        sol="Faltou ':' na linha do 'def'"
        erro_def+=1
        
    if "π" in erro:
        sol="π é math.pi"
        erro_pi+=1
        
    if ")(" in erro:
        sol="esqueceu o sinal de *"
        erro_vezes+=1
        
    else:
        lista_tipos_erros.append(erro)
        
    df_sintaxe["possivel_solucao"][ind]= sol

# %%
lista_tipos_erros[0:20]
# Out:
# ['    y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/σ)**2)',
#  '    if x',
#  '    y=1/sigma*2*math.pi)**0.5)math.e**-0.5*x-mi)/sigma)**2)',
#  '   print(calcula_gaussiana(0,0,1))',
#  '        return 0\n',
#  '   from import math e, sqrt, pi',
#  '    Import numpy as np',
#  '   print calcula_gaussiana(10, 12, 11)',
#  '    f=1/σ*2* math.pi)**1/2))*math.exp-0.5*x-μ)/σ)**2):',
#  '   g=(1/sigma*(2pi)**(-1/2)*e**(0,5((x-mi)/sigma)*2)',
#  '    f(x,μ,σ) =(1/(σ*((2*math.pi)**0.5))**(-0.5*((x-μ)/+σ)**2)\n',
#  "')",
#  "')",
#  '    calculo = (1/(sigma*(2*math.pi)**(1/2))*math.e**(-0,5*((x-mi)/sigma)**2)\n',
#  '    y = (1/sigma*(2*math.pi)**(1/2))*math.e**((-0.5)*(((x-mi)/sigma)**2)\n',
#  '    resultado = (1/(z*sqrt(2*math.pi))**((-0.5*((x-y)/σ)**2))\n',
#  'def calcula_gaussiana(x,μ,σ):\n',
#  '    a = y * z',
#  '   b=2,71**(-0.5*((x-mi)/sigma)**2)',
#  '    y = (1/sigma*(2*math.pi)**(0.5)*math.exp((-0.5)*((x-mi)/sigma)**2)\n']

# %%
erros = {'tipos': ["erro_import", "erro_antes_do_return", "erro_parenteses", "erro_potencia", "erro_if", "erro_while", "erro_for", "erro_def", "erro_pi", "erro_vezes"],
        'quantidade': [erro_import,erro_antes_do_return,erro_parenteses,erro_potencia,erro_if, erro_while,erro_for, erro_def, erro_pi,erro_vezes]
        }

df_classificacao = pd.DataFrame(erros, columns = ['tipos', 'quantidade'])

# %%
df_sintaxe
# Out:
#                                                    erro  \
# 1         y=1/σ*2import.pi)**1/2)import exp-0.5x-μ)/...
# 3                                                  if x
# 4         y=1/sigma*2*math.pi)**0.5)math.e**-0.5*x-m...
# 7                       print(calcula_gaussiana(0,0,1))
# 11                                           return 0\n
# 17                         from import math e, sqrt, pi
# 23                                   Import numpy as np
# 24                  print calcula_gaussiana(10, 12, 11)
# 26        f=1/σ*2* math.pi)**1/2))*math.exp-0.5*x-μ)...
# 32       g=(1/sigma*(2pi)**(-1/2)*e**(0,5((x-mi)/sig...
# 34        f(x,μ,σ) =(1/(σ*((2*math.pi)**0.5))**(-0.5...
# 36                                                   ')
# 37                                                   ')
# 38        calculo = (1/(sigma*(2*math.pi)**(1/2))*ma...
# 39        y = (1/sigma*(2*math.pi)**(1/2))*math.e**(...
# 41        resultado = (1/(z*sqrt(2*math.pi))**((-0.5...
# 42                      def calcula_gaussiana(x,μ,σ):\n
# 48                                            a = y * z
# 50                     b=2,71**(-0.5*((x-mi)/sigma)**2)
# 57        y = (1/sigma*(2*math.pi)**(0.5)*math.exp((...
# 63                      print(calcula_gaussiana(0,0,1))
# 65                                            f = a * b
# 72        equacao = (1 / (sigma((2*math.pi)**(1/2)))...
# 74                                if x,mi,sigma!=0,0,0:
# 78                                                   ')
# 81        f= (1/sig*math.sqrt(2*math.pi))*(math.exp(...
# 86                                     math import sqrt
# 95                                         1/sqrt2*pi))
# 97                                                   1)
# 98        f= 1/(sigma*math.sqrt(2*math.pi))*math.e**...
# ...                                                 ...
# 2236                                        import.math
# 2237      f=(1/(sig*(math.sqrt(2*(math.pi))))**(-(1/...
# 2238      f = (1/(o*((2*math.pi)**1/2))*math.e**(-0....
# 2244             parte2 = math.exp-0.5*x-mi)/sigma)**2)
# 2247                             1/math.sqrt2*math.pi))
# 2251                                          l = a * b
# 2256                                            c = a*b
# 2259      y = float((1/(sigma*(2 * math.pi)**(1/2)))...
# 2262  \tf=(1/(σ*(2*math.pi)**(1/2))*math.exp(-0.5*((...
# 2267                                       5x−yz) ** 2)
# 2271                       from import math e, sqrt, pi
# 2273      f = (1/sig*math.sqrt(2*math.pi))*(math.exp...
# 2275      f = 1/sigma*2*math.pi)**0.5))math.exp-0.5x...
# 2276                                            c = a*b
# 2282      form = (1/ (sigma((2*math.pi)**(1/2)))) * ...
# 2283                                         \\sigma) :
# 2285      resultado = (1 / (σ * sqrt(2 * math.pi)) *...
# 2292      gau = (math.e ** (-0.5 * ( (x - μ) /  σ  )...
# 2293                  def calcula_gaussiana(x,mi,sigma)
# 2294                          71**-1/2*x−mi)/sigma)**2)
# 2296                                           d=a*b)*c
# 2297      a=(1/(sigma*((2*math.pi)**(1/2))*math.exp)...
# 2299                   def calcula_gausssiana(x,μ,σ):\n
# 2305     f = (1/(sigma*math.sqrt(2*math.pi)))*math.e...
# 2307                       5\\frac{x-\\mu}{\\sigma})2)}
# 2308      f=1/σ2* math.pi)**1/2)math.exp-0.5*x-μ)/σ)...
# 2309      calculo = (1/(σ*math.sqrt(2*math.pi))**((-...
# 2313                      b = exp((-0,5(((x-m)/s)**2)\n
# 2314                                              def x
# 2315                       B = math.e0.5*x-mi)/sigma)2)
#
#                                            tipo_do_erro  \
# 1                           SyntaxError: invalid syntax
# 3                           SyntaxError: invalid syntax
# 4                           SyntaxError: invalid syntax
# 7                           SyntaxError: invalid syntax
# 11            SyntaxError: unexpected EOF while parsing
# 17                          SyntaxError: invalid syntax
# 23                          SyntaxError: invalid syntax
# 24                          SyntaxError: invalid syntax
# 26                          SyntaxError: invalid syntax
# 32                          SyntaxError: invalid syntax
# 34                          SyntaxError: invalid syntax
# 36          SyntaxError: can\'t assign to function call
# 37          SyntaxError: can\'t assign to function call
# 38                          SyntaxError: invalid syntax
# 39                          SyntaxError: invalid syntax
# 41                          SyntaxError: invalid syntax
# 42            SyntaxError: unexpected EOF while parsing
# 48                          SyntaxError: invalid syntax
# 50                          SyntaxError: invalid syntax
# 57                          SyntaxError: invalid syntax
# 63                          SyntaxError: invalid syntax
# 65                          SyntaxError: invalid syntax
# 72            SyntaxError: unexpected EOF while parsing
# 74                          SyntaxError: invalid syntax
# 78             SyntaxError: \'return\' outside function
# 81                          SyntaxError: invalid syntax
# 86                          SyntaxError: invalid syntax
# 95            SyntaxError: unexpected EOF while parsing
# 97            SyntaxError: unexpected EOF while parsing
# 98                          SyntaxError: invalid syntax
# ...                                                 ...
# 2236                        SyntaxError: invalid syntax
# 2237                        SyntaxError: invalid syntax
# 2238                        SyntaxError: invalid syntax
# 2244                        SyntaxError: invalid syntax
# 2247          SyntaxError: unexpected EOF while parsing
# 2251                        SyntaxError: invalid syntax
# 2256                        SyntaxError: invalid syntax
# 2259                        SyntaxError: invalid syntax
# 2262                        SyntaxError: invalid syntax
# 2267       SyntaxError: invalid character in identifier
# 2271                        SyntaxError: invalid syntax
# 2273                        SyntaxError: invalid syntax
# 2275                        SyntaxError: invalid syntax
# 2276                        SyntaxError: invalid syntax
# 2282                        SyntaxError: invalid syntax
# 2283  SyntaxError: unexpected character after line c...
# 2285                        SyntaxError: invalid syntax
# 2292                        SyntaxError: invalid syntax
# 2293                        SyntaxError: invalid syntax
# 2294       SyntaxError: invalid character in identifier
# 2296                        SyntaxError: invalid syntax
# 2297                        SyntaxError: invalid syntax
# 2299                        SyntaxError: invalid syntax
# 2305                        SyntaxError: invalid syntax
# 2307  SyntaxError: unexpected character after line c...
# 2308                        SyntaxError: invalid syntax
# 2309                        SyntaxError: invalid syntax
# 2313                        SyntaxError: invalid syntax
# 2314                        SyntaxError: invalid syntax
# 2315                        SyntaxError: invalid syntax
#
#                                      id                              linha  \
# 1     ch3_2019_08_13_16_52_03_378932.py                                  3
# 3     ch3_2020_02_28_17_44_32_436097.py                                  3
# 4     ch3_2019_03_01_12_59_50_648548.py                                  3
# 7     ch3_2020_03_18_23_48_15_310305.py                                 10
# 11    ch3_2019_03_30_20_28_09_678811.py                                  5
# 17    ch3_2020_03_09_13_49_29_497280.py                                  1
# 23    ch3_2020_09_21_18_42_03_389570.py                                  1
# 24    ch3_2020_08_04_15_47_57_054802.py                                  5
# 26    ch3_2019_08_12_17_09_58_433774.py                                  3
# 32    ch3_2020_09_29_19_01_20_963868.py                                  2
# 34    ch3_2019_06_05_01_20_09_945293.py                                  3
# 36    ch3_2020_03_25_19_08_34_352508.py                                  2
# 37    ch3_2020_03_02_18_45_49_216760.py                                  2
# 38    ch3_2020_03_09_13_38_03_494630.py                                  3
# 39    ch3_2020_03_03_10_10_14_055491.py                                  3
# 41    ch3_2019_03_14_19_31_10_022969.py                                  3
# 42    ch3_2020_09_23_20_30_53_343376.py                                  2
# 48    ch3_2020_03_23_14_55_07_251707.py                                  5
# 50    ch3_2020_03_31_18_21_08_348102.py                                  4
# 57    ch3_2019_03_11_21_58_43_396919.py                                  3
# 63    ch3_2020_03_03_17_29_08_273899.py                                 10
# 65    ch3_2020_03_23_14_54_35_351935.py                                  5
# 72    ch3_2020_09_09_12_11_29_735802.py                                  3
# 74    ch3_2019_03_09_17_39_36_402103.py                                  3
# 78    ch3_2019_08_13_19_43_22_340603.py                                  4
# 81    ch3_2020_04_10_20_37_39_895697.py                                  4
# 86    ch3_2019_08_16_19_15_13_019576.py                                  1
# 95    ch3_2020_03_02_21_35_28_782122.py  raceback (most recent call last):
# 97    ch3_2020_03_09_14_03_07_787857.py  raceback (most recent call last):
# 98    ch3_2020_03_09_19_09_40_205386.py                                  3
# ...                                 ...                                ...
# 2236  ch3_2019_03_12_21_10_44_924213.py                                  1
# 2237  ch3_2019_05_29_20_31_32_260220.py                                  4
# 2238  ch3_2020_09_08_17_30_19_635442.py                                  3
# 2244  ch3_2020_03_02_19_45_08_686566.py                                  5
# 2247  ch3_2020_04_06_18_54_42_307975.py  raceback (most recent call last):
# 2251  ch3_2020_03_23_14_53_58_631703.py                                  5
# 2256  ch3_2020_03_04_20_07_24_339955.py                                  6
# 2259  ch3_2019_08_26_20_23_52_343763.py                                  3
# 2262  ch3_2019_08_13_18_22_43_129570.py                                  3
# 2267  ch3_2020_09_09_12_15_02_756573.py  raceback (most recent call last):
# 2271  ch3_2020_03_09_13_48_29_232954.py                                  1
# 2273  ch3_2020_04_10_20_31_14_492924.py                                  4
# 2275  ch3_2019_08_14_13_30_47_108204.py                                  5
# 2276  ch3_2020_03_04_20_07_43_567598.py                                  6
# 2282  ch3_2020_09_09_12_04_43_548755.py                                  3
# 2283  ch3_2020_09_14_14_03_25_072072.py  raceback (most recent call last):
# 2285  ch3_2020_08_31_18_44_55_201192.py                                  3
# 2292  ch3_2020_09_09_20_18_58_431532.py                                  3
# 2293  ch3_2020_09_09_20_41_11_770857.py                                  3
# 2294  ch3_2020_03_09_20_28_58_798238.py  raceback (most recent call last):
# 2296  ch3_2020_09_09_14_29_37_403356.py                                  6
# 2297  ch3_2019_03_29_14_07_34_917203.py                                  3
# 2299  ch3_2019_03_07_18_57_42_939362.py                                  3
# 2305  ch3_2019_08_21_17_54_12_801185.py                                  3
# 2307  ch3_2020_03_23_10_14_53_153109.py  raceback (most recent call last):
# 2308  ch3_2019_08_12_17_07_36_036992.py                                  3
# 2309  ch3_2019_03_13_20_36_46_064099.py                                  3
# 2313  ch3_2020_03_04_20_08_39_273348.py                                  5
# 2314  ch3_2019_09_11_23_12_24_127271.py                                  1
# 2315  ch3_2020_03_04_19_49_40_592877.py                                  4
#
#       passou                                   possivel_solucao
# 1      False  Verifique a maneira com que está realizando o ...
# 3      False                        Faltou ':' na linha do 'if'
# 4      False                                                 --
# 7      False                                                 --
# 11     False                                                 --
# 17     False  Verifique a maneira com que está realizando o ...
# 23     False  Verifique a maneira com que está realizando o ...
# 24     False                                                 --
# 26     False                                                 --
# 32     False                        Faltou fechar um parênteses
# 34     False                        Faltou fechar um parênteses
# 36     False                                                 --
# 37     False                                                 --
# 38     False                        Faltou fechar um parênteses
# 39     False                        Faltou fechar um parênteses
# 41     False                        Faltou fechar um parênteses
# 42     False                                                 --
# 48     False                                                 --
# 50     False                                                 --
# 57     False                        Faltou fechar um parênteses
# 63     False                                                 --
# 65     False                                                 --
# 72     False                        Faltou fechar um parênteses
# 74     False                                                 --
# 78     False                                                 --
# 81     False                        Faltou fechar um parênteses
# 86     False  Verifique a maneira com que está realizando o ...
# 95     False                                                 --
# 97     False                                                 --
# 98     False                        Faltou fechar um parênteses
# ...      ...                                                ...
# 2236   False  Verifique a maneira com que está realizando o ...
# 2237   False                        Faltou fechar um parênteses
# 2238   False                        Faltou fechar um parênteses
# 2244   False                                                 --
# 2247   False                                                 --
# 2251   False                                                 --
# 2256   False                                                 --
# 2259   False                        Faltou fechar um parênteses
# 2262   False                        Faltou fechar um parênteses
# 2267   False                                                 --
# 2271   False  Verifique a maneira com que está realizando o ...
# 2273   False                        Faltou fechar um parênteses
# 2275   False                                                 --
# 2276   False                                                 --
# 2282   False                       Faltou ':' na linha do 'for'
# 2283   False                                                 --
# 2285   False                        Faltou fechar um parênteses
# 2292   False                        Faltou fechar um parênteses
# 2293   False                       Faltou ':' na linha do 'def'
# 2294   False                                                 --
# 2296   False                                                 --
# 2297   False                              esqueceu o sinal de *
# 2299   False                                                 --
# 2305   False                         Faltou abrir um parênteses
# 2307   False                                                 --
# 2308   False                                                 --
# 2309   False                        Faltou fechar um parênteses
# 2313   False                        Faltou fechar um parênteses
# 2314   False                       Faltou ':' na linha do 'def'
# 2315   False                                                 --
#
# [676 rows x 6 columns]

# %%
df_classificacao.set_index("tipos")
# Out:
#                       quantidade
# tipos
# erro_import                   41
# erro_antes_do_return           0
# erro_parenteses              353
# erro_potencia                  1
# erro_if                        8
# erro_while                     0
# erro_for                       5
# erro_def                      31
# erro_pi                       16
# erro_vezes                     4

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_axes([0,0,1,1])
ax.bar(df_classificacao["tipos"], df_classificacao["quantidade"])
plt.show()

# %%
# f, ax = plt.subplots(figsize = (32,20))
# plt.figure(figsize = (640,200))
erros = df_sintaxe["possivel_solucao"]
users = df_sintaxe["usuario"]
table = pd.crosstab(erros, users)
# plot=sns.heatmap(table,ax=ax, annot=True, cmap="YlGnBu")
# f.savefig("heatmap.png", dpi=200)
table

# %% [markdown]
# ## Digite o ID de um usuário para descobrir seus principais erros

# %% [markdown]
# ### Selecione o usuário:

# %%
usuario = "user_086"

# %%
table[usuario]

# %%
errors = df_sintaxe.loc[df_sintaxe["usuario"]==usuario]
errors.loc[:, ["erro", "linha","linha","detalhes","possivel_solucao"]]
